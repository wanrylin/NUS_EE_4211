# %% [markdown]
# # Question 3

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import requests
import json
import pandas as pd
import datetime as dt
import os
import numpy as np
import random
import warnings
import sklearn.linear_model as lm
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PolynomialFeatures as PF
from sklearn.metrics import r2_score,mean_absolute_error
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from matplotlib import mlab
from matplotlib import rcParams


warnings.filterwarnings("ignore")

#pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)
#np.set_printoptions(threshold=np.inf)

# %% [markdown]
# ## Data collecting blocks. No need to run because they were download in advanced with csv.

# %%
# grab certain time data and auto-repeat when "time out"
def timegraber_timeout(lstime = None):
    
    # input args processing
    if lstime is None:
        year = 2022
        month = 4
        day = 1
        hour = 0
        minute = 20
        second = 0 
    elif len(lstime) != 6:
        raise IndexError("lenght of list expects 6")
    else:
        year = lstime[0]
        month = lstime[1]
        day = lstime[2]
        hour = lstime[3]
        minute = lstime[4]
        second = lstime[5]
        
        # generate time
    Ddate = dt.datetime(year,month,day,hour,minute,second)

    # step
 #   deltat = dt.timedelta(hour = 1)
    loop = 1

    # update data
    while loop:

        # concatenate datetime
        date_time = f'date_time={str(Ddate.year)}-{str(Ddate.month).zfill(2)}-{str(Ddate.day).zfill(2)}T{str(Ddate.hour).zfill(2)}%3A{str(Ddate.minute).zfill(2)}%3A{str(Ddate.second).zfill(2)}'

        filename = f'EE4211carpark_date_{date_time}.json'
        # do not repeat download and write data
        if os.path.exists(filename) == False:
            # get API site
            site = f'https://api.data.gov.sg/v1/transport/carpark-availability?{date_time}'
            print(site)
            response_API = requests.get(site)
            data = response_API.text
            data = json.loads(data)

            # API may be timed out
            # when time out reget API
            if "message" in data:
                loop = 1
                print("time out")
                continue

            # no timed out then get timestamp
            timestamp = data['items'][0]["timestamp"]
            # get carpark data
            carpark = data['items'][0]["carpark_data"]
            with open(filename, 'w') as fp:
                json.dump(carpark, fp)

        # read file
        df = pd.read_json(filename)
        # reconstuct the frame of data
        for heading in ("total_lots","lot_type","lots_available"):
            df[heading] = df["carpark_info"].apply(lambda x: x[0][heading])
        df = df.drop(["carpark_info"], axis=1)
#        print(filename,"collected")
        loop = 0
        
    return df

# %% [markdown]
# ### Getting July data

# %%
# The start time of one-month interval
month = 7
day = 1
hour = 0
time_origin = [2022,month,day,hour,20,0]
df_origin = timegraber_timeout(time_origin)
#display(df_origin)

# Change the data to column name
colname = '_'.join(str(i) for i in time_origin)
#print(colname)

# Set up whole dataframe. Rename the column
total_number = df_origin.iloc[:,[0,3]]
df_whole = df_origin.rename(columns={'lots_available':colname})
df_whole = df_whole.drop(df_whole.columns[[1,2]],axis=1)


# Sort the whole dataframe
df_whole = df_whole.sort_values(by=['carpark_number','lot_type'])
#display(df_whole)

# Loop for a month

# gather new data
for day in range(1,32):
    for hour in range(24):
        time_new = [2022,month,day,hour,20,0]
        if time_new == time_origin:
            continue
        df_new = timegraber_timeout(time_new)
        # Change the data to column name
        colname = '_'.join(str(i) for i in time_new)
        #print(colname)
        # Rename the column
        new_number = df_new.iloc[:,[0,2,3]]
        df_new = df_new.rename(columns={'lots_available':colname})
        # Shape the new data
        
        df_new = df_new.drop(df_new.columns[[1,2]],axis=1)
        df_new = df_new.sort_values(by=['carpark_number','lot_type'])
        
        #display(df_new)
        #df_whole = pd.merge(df_whole,df_new,on=['carpark_number','total_lots','lot_type'],how='outer')
        df_whole = pd.merge(df_whole,df_new,on=['carpark_number','lot_type'],how='outer')
        total_number = pd.merge(total_number,new_number,on=['carpark_number','lot_type'],how='outer')
    print('Comparation finished for',day,'day.')
july_whole = df_whole.sort_values(by=['carpark_number','lot_type'])
display(july_whole)
july_total_lots = total_number.sort_values(by=['carpark_number','lot_type'])
display(july_total_lots)

# %% [markdown]
# ### Getting Augest data

# %%
# The start time of one-month interval
month = 8
day = 1
hour = 0
time_origin = [2022,month,day,hour,20,0]
df_origin = timegraber_timeout(time_origin)
#display(df_origin)

# Change the data to column name
colname = '_'.join(str(i) for i in time_origin)
#print(colname)

# Set up whole dataframe. Rename the column
total_number = df_origin.iloc[:,[0,3]]
df_whole = df_origin.rename(columns={'lots_available':colname})
df_whole = df_whole.drop(df_whole.columns[[1,2]],axis=1)


# Sort the whole dataframe
df_whole = df_whole.sort_values(by=['carpark_number','lot_type'])
#display(df_whole)

# Loop for a month

# gather new data
for day in range(1,32):
    for hour in range(24):
        time_new = [2022,month,day,hour,20,0]
        if time_new == time_origin:
            continue
        df_new = timegraber_timeout(time_new)
        # Change the data to column name
        colname = '_'.join(str(i) for i in time_new)
        #print(colname)
        # Rename the column
        new_number = df_new.iloc[:,[0,2,3]]
        df_new = df_new.rename(columns={'lots_available':colname})
        # Shape the new data
        
        df_new = df_new.drop(df_new.columns[[1,2]],axis=1)
        df_new = df_new.sort_values(by=['carpark_number','lot_type'])
        
        #display(df_new)
        #df_whole = pd.merge(df_whole,df_new,on=['carpark_number','total_lots','lot_type'],how='outer')
        df_whole = pd.merge(df_whole,df_new,on=['carpark_number','lot_type'],how='outer')
        total_number = pd.merge(total_number,new_number,on=['carpark_number','lot_type'],how='outer')
    print('Comparation finished for',day,'day.')
aug_whole = df_whole.sort_values(by=['carpark_number','lot_type'])
display(aug_whole)
aug_total_lots = total_number.sort_values(by=['carpark_number','lot_type'])
display(aug_total_lots)

# %% [markdown]
# ### Read data from .csv

# %%
#drop because: to_csv(index=True)，include row-index
july_whole = pd.read_csv("july_whole.csv")
july_whole = july_whole.drop(july_whole.columns[0],axis=1)
#july_whole = july_whole.sort_values(by=['carpark_number','lot_type'])

july_total_lots = pd.read_csv("july_total_lots.csv")
july_total_lots = july_total_lots.drop(july_total_lots.columns[0],axis=1)
#july_total_lots = july_total_lots.sort_values(by=['carpark_number','lot_type'])
#display(july_whole)
#display(july_total_lots)

aug_whole = pd.read_csv("aug_whole.csv")
aug_whole = aug_whole.drop(aug_whole.columns[0],axis=1)
#aug_whole = aug_whole.sort_values(by=['carpark_number','lot_type'])

aug_total_lots = pd.read_csv("aug_total_lots.csv")
aug_total_lots = aug_total_lots.drop(aug_total_lots.columns[0],axis=1)
#aug_total_lots = aug_total_lots.sort_values(by=['carpark_number','lot_type'])
display(aug_whole)
display(aug_total_lots)
# Out:
#      carpark_number lot_type  2022_8_1_0_20_0  2022_8_1_1_20_0  \
# 0               A10        C             23.0             21.0
# 1              A100        C             26.0             27.0
# 2               A11        C            143.0            143.0
# 3               A12        C             93.0             91.0
# 4               A13        C             92.0             90.0
# ...             ...      ...              ...              ...
# 2160             Y8        C            281.0            283.0
# 2161           Y82M        C            159.0            153.0
# 2162             Y9        C            128.0            130.0
# 2163            YHS        C             26.0             26.0
# 2164            YHS        Y              NaN              NaN
#
#       2022_8_1_2_20_0  2022_8_1_3_20_0  2022_8_1_4_20_0  2022_8_1_5_20_0  \
# 0                19.0             19.0             18.0             17.0
# ...

# %% [markdown]
# Clean the data
#
# july_wholereal, july_lots, aug_wholereal, aug_lots

# %%
#JULY

print('Carparks without data for the most of time in July: ')
july_wholenan = july_whole[july_whole.isnull().T.any()]
#display(july_wholenan)

july_wholereal = july_whole.drop(july_wholenan.index)
july_wholereal = july_wholereal.reset_index(drop=True)
print('Cleaned data: ')
display(july_wholereal)
#july_wholereal.to_csv('july_wholereal.csv')

# Deal with the total lots of each carpark
# Clean nan
july_lots_real = july_total_lots.drop(july_wholenan.index)
july_lots_real = july_lots_real.reset_index(drop=True)
#display(july_lots_real)

# Turn to int and get the one number of total lots of each
july_lots = july_lots_real.drop(july_lots_real.columns[[0,1]],axis=1).astype(int)
#display(july_lots)
print('The number of total lots of each carpark:')
july_lots = july_lots.T.max()
july_lots[july_lots == 0] = 1
display(july_lots)

#AUG

print('Carparks without data for the most of time in Aug: ')
aug_wholenan = aug_whole[aug_whole.isnull().T.any()]
#display(aug_wholenan)

aug_wholereal = aug_whole.drop(aug_wholenan.index)
aug_wholereal = aug_wholereal.reset_index(drop=True)
print('Cleaned data: ')
display(aug_wholereal)
#aug_wholereal.to_csv('aug_wholereal.csv')

# Deal with the total lots of each carpark
# Clean nan
aug_lots_real = aug_total_lots.drop(aug_wholenan.index)
aug_lots_real = aug_lots_real.reset_index(drop=True)
#display(aug_lots_real)

# Turn to int and get the one number of total lots of each
aug_lots = aug_lots_real.drop(aug_lots_real.columns[[0,1]],axis=1).astype(int)
#display(aug_lots)
print('The number of total lots of each carpark:')
aug_lots = aug_lots.T.max()
aug_lots[aug_lots == 0] = 1
display(aug_lots)
# Out:
# Carparks without data for the most of time in July:
# Cleaned data:
#      carpark_number lot_type  2022_7_1_0_20_0  2022_7_1_1_20_0  \
# 0               A10        C             26.0             23.0
# 1              A100        C             36.0             35.0
# 2               A11        C            134.0            132.0
# 3               A12        C             88.0             87.0
# 4               A13        C             92.0             90.0
# ...             ...      ...              ...              ...
# 1959           Y78M        C             72.0             66.0
# 1960             Y8        C            296.0            298.0
# 1961           Y82M        C            267.0            267.0
# 1962             Y9        C            108.0            110.0
# 1963            YHS        C             26.0             26.0
#
#       2022_7_1_2_20_0  2022_7_1_3_20_0  2022_7_1_4_20_0  2022_7_1_5_20_0  \
# ...

# %%
# JULY Availablity

july_div = july_wholereal.drop(july_wholereal.columns[[0,1]],axis=1).astype(int)
july_div = july_div.div(july_lots,axis=0)
july_div[july_div>1] = 1
display(july_div)

# AUG Availablity

aug_div = aug_wholereal.drop(aug_wholereal.columns[[0,1]],axis=1).astype(int)
aug_div = aug_div.div(aug_lots,axis=0)
aug_div[aug_div>1] = 1
display(aug_div)
# Out:
#       2022_7_1_0_20_0  2022_7_1_1_20_0  2022_7_1_2_20_0  2022_7_1_3_20_0  \
# 0            0.406250         0.359375         0.328125         0.328125
# 1            0.562500         0.546875         0.546875         0.515625
# 2            0.364130         0.358696         0.347826         0.339674
# 3            0.429268         0.424390         0.419512         0.424390
# 4            0.462312         0.452261         0.452261         0.472362
# ...               ...              ...              ...              ...
# 1959         0.333333         0.305556         0.287037         0.282407
# 1960         0.424677         0.427547         0.420373         0.395983
# 1961         0.782991         0.782991         0.782991         0.782991
# 1962         0.412214         0.419847         0.412214         0.408397
# 1963         0.406250         0.406250         0.406250         0.406250
#
#       2022_7_1_4_20_0  2022_7_1_5_20_0  2022_7_1_6_20_0  2022_7_1_7_20_0  \
# ...

# %% [markdown]
# ## 3.1 firstly classify the parking lots into different area, then, calculate the saturation index in every area, and finally, provide the areas with the highest saturation index.

# %%
# 直接以首字母区分
july_div_area = july_div
july_div_area.insert(0,'carpark_number',july_wholereal['carpark_number'].tolist())
july_div_area.insert(0,'area','')
display(july_div_area)
# Out:
#      area carpark_number  2022_7_1_0_20_0  2022_7_1_1_20_0  2022_7_1_2_20_0  \
# 0                    A10         0.406250         0.359375         0.328125
# 1                   A100         0.562500         0.546875         0.546875
# 2                    A11         0.364130         0.358696         0.347826
# 3                    A12         0.429268         0.424390         0.419512
# 4                    A13         0.462312         0.452261         0.452261
# ...   ...            ...              ...              ...              ...
# 1959                Y78M         0.333333         0.305556         0.287037
# 1960                  Y8         0.424677         0.427547         0.420373
# 1961                Y82M         0.782991         0.782991         0.782991
# 1962                  Y9         0.412214         0.419847         0.412214
# 1963                 YHS         0.406250         0.406250         0.406250
#
# ...

# %%
# 直接以首字母区分
aug_div_area = aug_div
aug_div_area.insert(0,'carpark_number',aug_wholereal['carpark_number'].tolist())
aug_div_area.insert(0,'area','')
display(aug_div_area)
# Out:
#      area carpark_number  2022_8_1_0_20_0  2022_8_1_1_20_0  2022_8_1_2_20_0  \
# 0                    A10         0.046000         0.042000         0.038000
# 1                   A100         0.406250         0.421875         0.421875
# 2                    A11         0.388587         0.388587         0.394022
# 3                    A12         0.453659         0.443902         0.439024
# 4                    A13         0.462312         0.452261         0.442211
# ...   ...            ...              ...              ...              ...
# 1959                Y78M         0.277778         0.259259         0.268519
# 1960                  Y8         0.403156         0.406026         0.397418
# 1961                Y82M         0.466276         0.448680         0.431085
# 1962                  Y9         0.488550         0.496183         0.496183
# 1963                 YHS         0.406250         0.406250         0.406250
#
# ...

# %% [markdown]
# **Adding the 'area' feature**

# %%
# A** 10~14
july_div_area.loc[july_div_area['carpark_number'].str.startswith('A'),'area'] = 10

july_div_area.loc[july_div_area['carpark_number'].str.startswith('AK'),'area'] = 11

july_div_area.loc[july_div_area['carpark_number'].str.startswith('AM'),'area'] = 12

july_div_area.loc[july_div_area['carpark_number'].str.startswith('AR'),'area'] = 13

july_div_area.loc[july_div_area['carpark_number'].str.startswith('AV'),'area'] = 14

july_div_area[july_div_area['carpark_number'].str.startswith('A')]
# Out:
#    area carpark_number  2022_7_1_0_20_0  2022_7_1_1_20_0  2022_7_1_2_20_0  \
# 0    10            A10         0.406250         0.359375         0.328125
# 1    10           A100         0.562500         0.546875         0.546875
# 2    10            A11         0.364130         0.358696         0.347826
# 3    10            A12         0.429268         0.424390         0.419512
# 4    10            A13         0.462312         0.452261         0.452261
# ..  ...            ...              ...              ...              ...
# 91   13           AR5M         0.527446         0.527446         0.527446
# 92   13           AR7L         0.500000         0.750000         0.750000
# 93   13           AR7M         0.393220         0.389831         0.386441
# 94   13            AR9         0.031250         0.031250         0.031250
# 95   14            AV1         0.714801         0.707581         0.707581
#
#     2022_7_1_3_20_0  2022_7_1_4_20_0  2022_7_1_5_20_0  2022_7_1_6_20_0  \
# ...

# %%
# B** 20~31
july_div_area.loc[july_div_area['carpark_number'].str.startswith('B'),'area'] = 20

july_div_area.loc[july_div_area['carpark_number'].str.startswith('BA'),'area'] = 21

july_div_area.loc[july_div_area['carpark_number'].str.startswith('BBM'),'area'] = 22

july_div_area.loc[july_div_area['carpark_number'].str.startswith('BE'),'area'] = 23

july_div_area.loc[july_div_area['carpark_number'].str.startswith('BH'),'area'] = 24

july_div_area.loc[july_div_area['carpark_number'].str.startswith('BJ'),'area'] = 25

july_div_area.loc[july_div_area['carpark_number'].str.startswith('BK'),'area'] = 26

july_div_area.loc[july_div_area['carpark_number'].str.startswith('BL'),'area'] = 27

july_div_area.loc[july_div_area['carpark_number'].str.startswith('BM'),'area'] = 28

july_div_area.loc[july_div_area['carpark_number'].str.startswith('BP'),'area'] = 29

july_div_area.loc[july_div_area['carpark_number'].str.startswith('BR'),'area'] = 30

july_div_area.loc[july_div_area['carpark_number'].str.startswith('BT'),'area'] = 31

july_div_area[july_div_area['carpark_number'].str.startswith('B')]
# Out:
#     area carpark_number  2022_7_1_0_20_0  2022_7_1_1_20_0  2022_7_1_2_20_0  \
# 96    20            B10         0.304264         0.308140         0.302326
# 97    20           B10M         0.990536         0.993691         0.974763
# 98    20            B11         0.380811         0.378833         0.405539
# 99    20            B14         0.293269         0.293269         0.293269
# 100   20            B16         0.480769         0.469780         0.464286
# ..   ...            ...              ...              ...              ...
# 361   31            BTM         0.465753         0.465753         0.465753
# 362   31           BTM2         0.723790         0.723790         0.723790
# 363   31           BTM3         0.300000         0.294444         0.288889
# 364   20           BVM2         0.678571         0.678571         0.678571
# 365   20            BWM         0.468182         0.459091         0.431818
#
# ...

# %%
# C** 40~45
july_div_area.loc[july_div_area['carpark_number'].str.startswith('C'),'area'] = 40

july_div_area.loc[july_div_area['carpark_number'].str.startswith('CC'),'area'] = 41

july_div_area.loc[july_div_area['carpark_number'].str.startswith('CK'),'area'] = 42

july_div_area.loc[july_div_area['carpark_number'].str.startswith('CL'),'area'] = 43

july_div_area.loc[july_div_area['carpark_number'].str.startswith('CR'),'area'] = 44

july_div_area.loc[july_div_area['carpark_number'].str.startswith('CV'),'area'] = 45


july_div_area[july_div_area['carpark_number'].str.startswith('C')]
# Out:
#     area carpark_number  2022_7_1_0_20_0  2022_7_1_1_20_0  2022_7_1_2_20_0  \
# 366   40            C10         0.374185         0.374185         0.374185
# 367   40            C11         0.643454         0.621170         0.640669
# 368   40            C12         0.588235         0.588235         0.588235
# 369   40           C13M         0.732143         0.732143         0.732143
# 370   40           C14M         0.542453         0.542453         0.542453
# ..   ...            ...              ...              ...              ...
# 521   45            CV1         0.872964         0.879479         0.892508
# 522   45            CV2         0.888889         0.925926         0.962963
# 523   45            CV3         0.627907         0.744186         0.755814
# 524   45           CVBK         0.123874         0.105856         0.108108
# 525   40             CY         0.032258         0.064516         0.064516
#
# ...

# %%
# D** 50~53

july_div_area.loc[july_div_area['carpark_number'].str.startswith('DR'),'area'] = 50

july_div_area.loc[july_div_area['carpark_number'].str.startswith('DS'),'area'] = 51

july_div_area.loc[july_div_area['carpark_number'].str.startswith('DW'),'area'] = 52

july_div_area.loc[july_div_area['carpark_number'].str.startswith('DU'),'area'] = 53

july_div_area[july_div_area['carpark_number'].str.startswith('D')]
# Out:
#     area carpark_number  2022_7_1_0_20_0  2022_7_1_1_20_0  2022_7_1_2_20_0  \
# 526   50           DRM1         0.772321         0.765625         0.756696
# 527   50           DRM2         0.497449         0.497449         0.492347
# 528   50           DRM3         0.673684         0.663158         0.656140
# 529   50           DRM4         0.067308         0.057692         0.048077
# 530   50           DRM5         0.119048         0.107143         0.107143
# 531   50            DRS         0.980377         0.979623         0.981887
# 532   51           DSR1         0.755556         0.755556         0.755556
# 533   51           DSR2         0.896104         0.896104         0.896104
# 534   51           DSRL         0.000000         0.000000         0.000000
# 535   53            DUX         0.571000         0.571000         0.571000
# 536   53           DUXM         0.621005         0.621005         0.621005
# ...

# %%
# E** F** G** 60~66

july_div_area.loc[july_div_area['carpark_number'].str.startswith('EC'),'area'] = 60

july_div_area.loc[july_div_area['carpark_number'].str.startswith('EI'),'area'] = 61

july_div_area.loc[july_div_area['carpark_number'].str.startswith('EP'),'area'] = 62

display(july_div_area[july_div_area['carpark_number'].str.startswith('E')])


july_div_area.loc[july_div_area['carpark_number'].str.startswith('F'),'area'] = 63

display(july_div_area[july_div_area['carpark_number'].str.startswith('F')])


july_div_area.loc[july_div_area['carpark_number'].str.startswith('G'),'area'] = 64

july_div_area.loc[july_div_area['carpark_number'].str.startswith('GM'),'area'] = 65

july_div_area.loc[july_div_area['carpark_number'].str.startswith('GS'),'area'] = 66

display(july_div_area[july_div_area['carpark_number'].str.startswith('G')])
# Out:
#     area carpark_number  2022_7_1_0_20_0  2022_7_1_1_20_0  2022_7_1_2_20_0  \
# 542   60            EC2         0.372064         0.348578         0.339926
# 543   60            EC3         0.413043         0.413043         0.434783
# 544   60            EC4         0.570175         0.561404         0.500000
# 545   60            EC7         0.212598         0.196850         0.188976
# 546   60            EC8         0.884848         0.884848         0.884848
# 547   60            ECM         0.533170         0.523342         0.525799
# 548   61            EI3         0.256604         0.203774         0.211321
# 549   62            EPL         0.444444         0.500000         0.500000
# 550   62            EPM         0.402098         0.419580         0.409091
# 551   62           EPML         0.000000         0.000000         0.000000
#
#      2022_7_1_3_20_0  2022_7_1_4_20_0  2022_7_1_5_20_0  2022_7_1_6_20_0  \
# ...

# %%
# H** 70~73

july_div_area.loc[july_div_area['carpark_number'].str.startswith('H'),'area'] = 70

july_div_area.loc[july_div_area['carpark_number'].str.startswith('HE'),'area'] = 71

july_div_area.loc[july_div_area['carpark_number'].str.startswith('HG'),'area'] = 72

july_div_area.loc[july_div_area['carpark_number'].str.startswith('HR'),'area'] = 73

display(july_div_area[july_div_area['carpark_number'].str.startswith('H')])
# Out:
#     area carpark_number  2022_7_1_0_20_0  2022_7_1_1_20_0  2022_7_1_2_20_0  \
# 578   70            H12         0.483146         0.483146         0.483146
# 579   70            H14         0.709091         0.709091         0.709091
# 580   70            H17         0.327511         0.323144         0.327511
# 581   70            H18         0.595238         0.601190         0.601190
# 582   70             H3         0.851351         0.851351         0.851351
# ..   ...            ...              ...              ...              ...
# 694   73            HR3         0.409692         0.405286         0.400881
# 695   73            HR4         0.592233         0.621359         0.611650
# 696   73            HR5         0.307692         0.329670         0.307692
# 697   73            HRM         0.536618         0.521971         0.515313
# 698   70            HVM         0.408859         0.403748         0.400341
#
# ...

# %%
# J** 80~86

july_div_area.loc[july_div_area['carpark_number'].str.startswith('J'),'area'] = 80

july_div_area.loc[july_div_area['carpark_number'].str.startswith('JB'),'area'] = 81

july_div_area.loc[july_div_area['carpark_number'].str.startswith('JC'),'area'] = 82

july_div_area.loc[july_div_area['carpark_number'].str.startswith('JK'),'area'] = 83

july_div_area.loc[july_div_area['carpark_number'].str.startswith('JM'),'area'] = 84

july_div_area.loc[july_div_area['carpark_number'].str.startswith('JR'),'area'] = 85

july_div_area.loc[july_div_area['carpark_number'].str.startswith('JS'),'area'] = 86

display(july_div_area[july_div_area['carpark_number'].str.startswith('J')])
# Out:
#     area carpark_number  2022_7_1_0_20_0  2022_7_1_1_20_0  2022_7_1_2_20_0  \
# 699   80             J1         0.326087         0.309783         0.307065
# 700   80            J10         0.228571         0.228571         0.222857
# 701   80            J11         0.519380         0.511628         0.480620
# 702   80            J12         0.534979         0.469136         0.448560
# 703   80            J14         0.223958         0.218750         0.208333
# ..   ...            ...              ...              ...              ...
# 856   86           JS4L         0.583333         0.583333         0.500000
# 857   86           JS5L         0.733333         0.533333         0.633333
# 858   86           JSA1         0.555556         0.539683         0.539683
# 859   86           JSR1         0.864322         0.864322         0.864322
# 860   86           JSR2         0.627319         0.617201         0.617201
#
# ...

# %%
# K** L** 90~98

july_div_area.loc[july_div_area['carpark_number'].str.startswith('K'),'area'] = 90

july_div_area.loc[july_div_area['carpark_number'].str.startswith('KA'),'area'] = 91

july_div_area.loc[july_div_area['carpark_number'].str.startswith('KB'),'area'] = 92

july_div_area.loc[july_div_area['carpark_number'].str.startswith('KE'),'area'] = 93

july_div_area.loc[july_div_area['carpark_number'].str.startswith('KJ'),'area'] = 94

july_div_area.loc[july_div_area['carpark_number'].str.startswith('KM'),'area'] = 95

july_div_area.loc[july_div_area['carpark_number'].str.startswith('KT'),'area'] = 96

july_div_area.loc[july_div_area['carpark_number'].str.startswith('KU'),'area'] = 97

display(july_div_area[july_div_area['carpark_number'].str.startswith('K')])


july_div_area.loc[july_div_area['carpark_number'].str.startswith('L'),'area'] = 98

display(july_div_area[july_div_area['carpark_number'].str.startswith('L')])
# Out:
#     area carpark_number  2022_7_1_0_20_0  2022_7_1_1_20_0  2022_7_1_2_20_0  \
# 861   90            K10         0.052083         0.041667         0.020833
# 862   90            K19         0.083333         0.062500         0.031250
# 863   90             K2         0.115789         0.115789         0.115789
# 864   90            K2T         0.041096         0.041096         0.041096
# 865   90            K52         0.509804         0.460784         0.460784
# 866   90             K7         0.937107         0.924528         0.911950
# 867   91            KAM         0.820707         0.818182         0.815657
# 868   91           KAML         1.000000         0.600000         1.000000
# 869   91           KAMS         1.000000         1.000000         1.000000
# 870   91            KAS         0.384615         0.346154         0.384615
# 871   92            KB1         0.259414         0.200837         0.142259
# ...

# %%
# M** N** 100~106

july_div_area.loc[july_div_area['carpark_number'].str.startswith('M'),'area'] = 100

july_div_area.loc[july_div_area['carpark_number'].str.startswith('ML'),'area'] = 101

july_div_area.loc[july_div_area['carpark_number'].str.startswith('MM'),'area'] = 102

july_div_area.loc[july_div_area['carpark_number'].str.startswith('MN'),'area'] = 103

july_div_area.loc[july_div_area['carpark_number'].str.startswith('MP'),'area'] = 104

july_div_area.loc[july_div_area['carpark_number'].str.startswith('MR'),'area'] = 105

july_div_area.loc[july_div_area['carpark_number'].str.startswith('N'),'area'] = 106

display(july_div_area[july_div_area['carpark_number'].str.startswith('M')])
display(july_div_area[july_div_area['carpark_number'].str.startswith('N')])
# Out:
#     area carpark_number  2022_7_1_0_20_0  2022_7_1_1_20_0  2022_7_1_2_20_0  \
# 919  100             M1         0.724359         0.724359         0.724359
# 920  100            M16         0.209677         0.169355         0.137097
# 921  100            M20         0.166667         0.166667         0.138889
# 922  100            M25         0.332547         0.304245         0.285377
# 923  100             M3         0.000000         0.000000         0.000000
# 924  100            M32         0.394886         0.394886         0.394886
# 925  100            M33         0.336000         0.304000         0.312000
# 926  100            M35         0.087912         0.043956         0.021978
# 927  100            M36         0.000000         0.000000         0.000000
# 928  100            M37         0.000000         0.000000         0.000000
# 929  100            M38         0.076923         0.102564         0.025641
# ...

# %%
# P** Q** 110~116

july_div_area.loc[july_div_area['carpark_number'].str.startswith('P'),'area'] = 110

july_div_area.loc[july_div_area['carpark_number'].str.startswith('PD'),'area'] = 111

july_div_area.loc[july_div_area['carpark_number'].str.startswith('PL'),'area'] = 112

july_div_area.loc[july_div_area['carpark_number'].str.startswith('PM'),'area'] = 113

july_div_area.loc[july_div_area['carpark_number'].str.startswith('PP'),'area'] = 114

july_div_area.loc[july_div_area['carpark_number'].str.startswith('PR'),'area'] = 115

display(july_div_area[july_div_area['carpark_number'].str.startswith('P')])


july_div_area.loc[july_div_area['carpark_number'].str.startswith('Q'),'area'] = 116

display(july_div_area[july_div_area['carpark_number'].str.startswith('Q')])
# Out:
#      area carpark_number  2022_7_1_0_20_0  2022_7_1_1_20_0  2022_7_1_2_20_0  \
# 974   110             P1         0.468153         0.445860         0.436306
# 975   110            P11         0.897959         0.897959         0.897959
# 976   110            P12         0.846774         0.838710         0.838710
# 977   110            P13         0.300000         0.293333         0.300000
# 978   110            P14         0.493355         0.483389         0.475083
# ...   ...            ...              ...              ...              ...
# 1137  115            PR6         0.721068         0.727003         0.727003
# 1138  115            PR7         0.084444         0.097778         0.080000
# 1139  115            PR8         0.025316         0.018987         0.025316
# 1140  115            PRM         0.857639         0.862847         0.868056
# 1141  115           PRS1         0.095238         0.047619         0.047619
#
# ...

# %%
# R**  120~121

july_div_area.loc[july_div_area['carpark_number'].str.startswith('RC'),'area'] = 120

july_div_area.loc[july_div_area['carpark_number'].str.startswith('RH'),'area'] = 121

display(july_div_area[july_div_area['carpark_number'].str.startswith('R')])
# Out:
#      area carpark_number  2022_7_1_0_20_0  2022_7_1_1_20_0  2022_7_1_2_20_0  \
# 1167  120            RC1         0.347561         0.335366         0.329268
# 1168  120            RC2         0.301075         0.284946         0.274194
# 1169  120            RC3         0.367041         0.363296         0.355805
# 1170  120            RCB         0.565625         0.565625         0.565625
# 1171  120            RCM         0.357616         0.357616         0.344371
# 1172  121            RH3         0.000000         0.000000         0.000000
# 1173  121            RHM         0.407295         0.407295         0.407295
# 1174  121           RHM2         0.536036         0.536036         0.536036
# 1175  121           RHM3         0.701238         0.701238         0.701238
# 1176  121           RHM4         0.244681         0.244681         0.244681
# 1177  121            RHS         0.000000         0.000000         0.000000
#
# ...

# %%
# S** 1126~139

july_div_area.loc[july_div_area['carpark_number'].str.startswith('S'),'area'] = 130

july_div_area.loc[july_div_area['carpark_number'].str.startswith('SA'),'area'] = 131

july_div_area.loc[july_div_area['carpark_number'].str.startswith('SB'),'area'] = 132

july_div_area.loc[july_div_area['carpark_number'].str.startswith('SD'),'area'] = 133

july_div_area.loc[july_div_area['carpark_number'].str.startswith('SE'),'area'] = 134

july_div_area.loc[july_div_area['carpark_number'].str.startswith('SG'),'area'] = 135

july_div_area.loc[july_div_area['carpark_number'].str.startswith('SH'),'area'] = 136

july_div_area.loc[july_div_area['carpark_number'].str.startswith('SI'),'area'] = 137

july_div_area.loc[july_div_area['carpark_number'].str.startswith('SK'),'area'] = 138

july_div_area.loc[july_div_area['carpark_number'].str.startswith('SL'),'area'] = 139

july_div_area.loc[july_div_area['carpark_number'].str.startswith('SM'),'area'] = 129

july_div_area.loc[july_div_area['carpark_number'].str.startswith('SP'),'area'] = 128

july_div_area.loc[july_div_area['carpark_number'].str.startswith('SR'),'area'] = 127

july_div_area.loc[july_div_area['carpark_number'].str.startswith('ST'),'area'] = 126

display(july_div_area[july_div_area['carpark_number'].str.startswith('S')])
# Out:
#      area carpark_number  2022_7_1_0_20_0  2022_7_1_1_20_0  2022_7_1_2_20_0  \
# 1178  130           S100         0.403986         0.387681         0.374094
# 1179  130           S102         0.405797         0.395652         0.391304
# 1180  130           S103         0.469945         0.461749         0.453552
# 1181  130           S104         0.359882         0.348083         0.342183
# 1182  130           S105         0.474114         0.468665         0.457766
# ...   ...            ...              ...              ...              ...
# 1430  128            SPS         0.795918         0.795918         0.795918
# 1431  126           STAM         0.328467         0.328467         0.328467
# 1432  126           STM1         0.337838         0.337838         0.337838
# 1433  126           STM2         0.462312         0.462312         0.462312
# 1434  126           STM3         0.000000         0.000000         0.000000
#
# ...

# %%
# T** 140

july_div_area.loc[july_div_area['carpark_number'].str.startswith('T'),'area'] = 140

july_div_area.loc[july_div_area['carpark_number'].str.startswith('TA'),'area'] = 141

july_div_area.loc[july_div_area['carpark_number'].str.startswith('TB'),'area'] = 142

july_div_area.loc[july_div_area['carpark_number'].str.startswith('TE'),'area'] = 143

july_div_area.loc[july_div_area['carpark_number'].str.startswith('TG'),'area'] = 144

july_div_area.loc[july_div_area['carpark_number'].str.startswith('TJ'),'area'] = 145

july_div_area.loc[july_div_area['carpark_number'].str.startswith('TM'),'area'] = 146

july_div_area.loc[july_div_area['carpark_number'].str.startswith('TP'),'area'] = 147

july_div_area.loc[july_div_area['carpark_number'].str.startswith('TR'),'area'] = 148

july_div_area.loc[july_div_area['carpark_number'].str.startswith('TW'),'area'] = 149

display(july_div_area[july_div_area['carpark_number'].str.startswith('T')])
# Out:
#      area carpark_number  2022_7_1_0_20_0  2022_7_1_1_20_0  2022_7_1_2_20_0  \
# 1435  140             T1         0.414044         0.401937         0.372881
# 1436  140            T11         0.256000         0.212000         0.244000
# 1437  140            T12         0.288000         0.268000         0.280000
# 1438  140            T13         0.390306         0.385204         0.385204
# 1439  140            T15         0.600000         0.633333         0.633333
# ...   ...            ...              ...              ...              ...
# 1677  149            TW4         0.150376         0.142857         0.139098
# 1678  149           TWM1         0.721649         0.716495         0.712629
# 1679  149           TWM2         0.749258         0.746291         0.737389
# 1680  149           TWM3         0.781563         0.779559         0.780561
# 1681  149           TWM4         0.515000         0.535000         0.490000
#
# ...

# %%
# U** W** 150

july_div_area.loc[july_div_area['carpark_number'].str.startswith('U'),'area'] = 150

july_div_area.loc[july_div_area['carpark_number'].str.startswith('UA'),'area'] = 151

july_div_area.loc[july_div_area['carpark_number'].str.startswith('UB'),'area'] = 152

display(july_div_area[july_div_area['carpark_number'].str.startswith('U')])


july_div_area.loc[july_div_area['carpark_number'].str.startswith('W'),'area'] = 153

july_div_area.loc[july_div_area['carpark_number'].str.startswith('WC'),'area'] = 154

display(july_div_area[july_div_area['carpark_number'].str.startswith('W')])
# Out:
#      area carpark_number  2022_7_1_0_20_0  2022_7_1_1_20_0  2022_7_1_2_20_0  \
# 1682  150             U1         0.294574         0.284884         0.279070
# 1683  150            U10         0.149533         0.116822         0.093458
# 1684  150            U11         0.000000         0.000000         0.000000
# 1685  150            U12         0.232859         0.222510         0.212160
# 1686  150            U13         0.239032         0.220877         0.216339
# ...   ...            ...              ...              ...              ...
# 1744  152           UBK4         0.245283         0.226415         0.113208
# 1745  152           UBK5         0.433566         0.412587         0.391608
# 1746  152           UBKM         0.568513         0.551020         0.551020
# 1747  152           UBM1         0.640044         0.628009         0.619256
# 1748  152           UBM2         0.583505         0.571134         0.562887
#
# ...

# %%
# Y** 160

july_div_area.loc[july_div_area['carpark_number'].str.startswith('Y'),'area'] = 160

display(july_div_area[july_div_area['carpark_number'].str.startswith('Y')])
# Out:
#      area carpark_number  2022_7_1_0_20_0  2022_7_1_1_20_0  2022_7_1_2_20_0  \
# 1879  160             Y1         0.577181         0.637584         0.644295
# 1880  160            Y10         0.370306         0.365066         0.360699
# 1881  160            Y11         0.328909         0.314159         0.299410
# 1882  160            Y12         0.295638         0.285945         0.277868
# 1883  160            Y13         0.236641         0.202290         0.194656
# ...   ...            ...              ...              ...              ...
# 1959  160           Y78M         0.333333         0.305556         0.287037
# 1960  160             Y8         0.424677         0.427547         0.420373
# 1961  160           Y82M         0.782991         0.782991         0.782991
# 1962  160             Y9         0.412214         0.419847         0.412214
# 1963  160            YHS         0.406250         0.406250         0.406250
#
# ...

# %%
# AUG

# A** 10~14
aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('A'),'area'] = 10

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('AK'),'area'] = 11

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('AM'),'area'] = 12

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('AR'),'area'] = 13

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('AV'),'area'] = 14

# B** 20~31
aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('B'),'area'] = 20

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('BA'),'area'] = 21

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('BBM'),'area'] = 22

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('BE'),'area'] = 23

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('BH'),'area'] = 24

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('BJ'),'area'] = 25

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('BK'),'area'] = 26

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('BL'),'area'] = 27

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('BM'),'area'] = 28

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('BP'),'area'] = 29

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('BR'),'area'] = 30

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('BT'),'area'] = 31

# C** 40~45
aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('C'),'area'] = 40

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('CC'),'area'] = 41

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('CK'),'area'] = 42

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('CL'),'area'] = 43

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('CR'),'area'] = 44

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('CV'),'area'] = 45

# D** 50~53

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('DR'),'area'] = 50

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('DS'),'area'] = 51

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('DW'),'area'] = 52

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('DU'),'area'] = 53

# E** F** G** 60~66

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('EC'),'area'] = 60

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('EI'),'area'] = 61

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('EP'),'area'] = 62


aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('F'),'area'] = 63


aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('G'),'area'] = 64

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('GM'),'area'] = 65

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('GS'),'area'] = 66

# H** 70~73

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('H'),'area'] = 70

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('HE'),'area'] = 71

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('HG'),'area'] = 72

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('HR'),'area'] = 73

# J** 80~86

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('J'),'area'] = 80

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('JB'),'area'] = 81

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('JC'),'area'] = 82

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('JK'),'area'] = 83

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('JM'),'area'] = 84

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('JR'),'area'] = 85

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('JS'),'area'] = 86

# K** L** 90~98

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('K'),'area'] = 90

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('KA'),'area'] = 91

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('KB'),'area'] = 92

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('KE'),'area'] = 93

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('KJ'),'area'] = 94

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('KM'),'area'] = 95

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('KT'),'area'] = 96

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('KU'),'area'] = 97


aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('L'),'area'] = 98

# M** N** 100~106

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('M'),'area'] = 100

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('ML'),'area'] = 101

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('MM'),'area'] = 102

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('MN'),'area'] = 103

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('MP'),'area'] = 104

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('MR'),'area'] = 105

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('N'),'area'] = 106

# P** Q** 110~116

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('P'),'area'] = 110

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('PD'),'area'] = 111

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('PL'),'area'] = 112

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('PM'),'area'] = 113

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('PP'),'area'] = 114

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('PR'),'area'] = 115


aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('Q'),'area'] = 116

# R**  120~121

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('RC'),'area'] = 120

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('RH'),'area'] = 121

# S** 1126~139

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('S'),'area'] = 130

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('SA'),'area'] = 131

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('SB'),'area'] = 132

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('SD'),'area'] = 133

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('SE'),'area'] = 134

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('SG'),'area'] = 135

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('SH'),'area'] = 136

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('SI'),'area'] = 137

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('SK'),'area'] = 138

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('SL'),'area'] = 139

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('SM'),'area'] = 129

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('SP'),'area'] = 128

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('SR'),'area'] = 127

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('ST'),'area'] = 126

# T** 140

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('T'),'area'] = 140

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('TA'),'area'] = 141

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('TB'),'area'] = 142

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('TE'),'area'] = 143

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('TG'),'area'] = 144

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('TJ'),'area'] = 145

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('TM'),'area'] = 146

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('TP'),'area'] = 147

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('TR'),'area'] = 148

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('TW'),'area'] = 149

# U** W** 150

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('U'),'area'] = 150

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('UA'),'area'] = 151

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('UB'),'area'] = 152


aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('W'),'area'] = 153

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('WC'),'area'] = 154

# Y** 160

aug_div_area.loc[aug_div_area['carpark_number'].str.startswith('Y'),'area'] = 160

# %%
july_div_area.to_csv('july_div_area.csv')
aug_div_area.to_csv('aug_div_area.csv')

# %% [markdown]
# **Availability curve of each area:**

# %%
july_div_area = pd.read_csv('july_div_area.csv')
july_div_area = july_div_area.drop(july_div_area.columns[0],axis=1)
aug_div_area = pd.read_csv('aug_div_area.csv')
aug_div_area = aug_div_area.drop(aug_div_area.columns[0],axis=1)

# empty df
average_area_july = pd.DataFrame()

# loop for the mean of each area
for id in july_div_area['area'].unique().astype(int):
    #print(id)
    average_area_july = pd.concat([average_area_july,july_div_area.loc[july_div_area['area'] == id].mean()],axis=1)
    
    
average_area_july = average_area_july.T.reset_index(drop=True)
display(average_area_july)

# empty df
average_area_aug = pd.DataFrame()

# loop for the mean of each area
for id in aug_div_area['area'].unique().astype(int):
    #print(id)
    average_area_aug = pd.concat([average_area_aug,aug_div_area.loc[aug_div_area['area'] == id].mean()],axis=1)
    
    
average_area_aug = average_area_aug.T.reset_index(drop=True)
display(average_area_aug)
# Out:
#      area  2022_7_1_0_20_0  2022_7_1_1_20_0  2022_7_1_2_20_0  2022_7_1_3_20_0  \
# 0    10.0         0.378225         0.379620         0.371423         0.370247
# 1    12.0         0.356279         0.342902         0.334855         0.345720
# 2    13.0         0.304760         0.336143         0.335558         0.333465
# 3    14.0         0.714801         0.707581         0.707581         0.718412
# 4    20.0         0.479026         0.473800         0.478280         0.473701
# ..    ...              ...              ...              ...              ...
# 93  151.0         0.264392         0.250441         0.247195         0.263008
# 94  152.0         0.449565         0.433037         0.406098         0.449462
# 95  153.0         0.424296         0.416790         0.411099         0.404114
# 96  154.0         0.471752         0.477880         0.480512         0.477015
# 97  160.0         0.371539         0.365952         0.360495         0.359548
#
# ...

# %% [markdown]
# ### Renew features of July and August

# %%
# Features, hour，week-day，number of weeks

july_x = []
weekday = [5,6,7,1,2,3,4]
for i in range(744):
    h = int((i%24))
    day_id = int((i%168)/24)
    day = weekday[day_id]
    week = int((i%768)/168) + 1


    july_x.append([h,day,week])

july_x = np.array(july_x)
#display(july_x)

aug_x = []
weekday = [1,2,3,4,5,6,7]
for i in range(744):
    h = int((i%24))
    day_id = int((i%168)/24)
    day = weekday[day_id]
    week = int((i%768)/168) + 1


    aug_x.append([h,day,week])

aug_x = np.array(aug_x)
display(aug_x)
# Out:
# array([[ 0,  1,  1],
#        [ 1,  1,  1],
#        [ 2,  1,  1],
#        ...,
#        [21,  3,  5],
#        [22,  3,  5],
#        [23,  3,  5]])

# %%
# Linear Regressor

# Standardize the data set
sc = StandardScaler()
sc.fit(july_x)
# not put X here because that will see the test set
july_x_std = sc.transform(july_x)
aug_x_std = sc.transform(aug_x)

july_y = average_area_july.loc[average_area_july['area'] == 10]\
       .drop(average_area_july.columns[[0]],axis=1).values[0]*100

lr = lm.LinearRegression()
lr.fit(july_x_std,july_y)

july_predict = lr.predict(july_x_std)

# Plot
fig, ax = plt.subplots(1, 1, figsize=(10, 3))
ax.plot(range(0,31*24), july_predict, '-g')
ax.plot(range(0,31*24), july_y, '--k', ms=1)
#ax.set_xlim(0, 31*24)
#ax.set_ylim(0, 1)
ax.set_title("Avaliable rate for July 'ANG MO KIO'")
plt.xlabel("hour")
plt.ylabel("avaliable rate %")
plt.grid()



aug_predict = lr.predict(aug_x_std)

aug_y = average_area_aug.loc[average_area_aug['area'] == 10]\
       .drop(average_area_aug.columns[[0]],axis=1).values[0]*100

print('LR prediction:')
print(f'r2 score: {r2_score(aug_y,aug_predict)}')
print(f'mean absolute error: {mean_absolute_error(aug_y,aug_predict)/100}')

fig, ax = plt.subplots(1, 1, figsize=(10, 3))
ax.plot(range(0,31*24), aug_predict, '-g')
ax.plot(range(0,31*24), aug_y, '--k', ms=1)
#ax.set_xlim(0, 31*24)
#ax.set_ylim(0, 1)
ax.set_title("Avaliable rate for August 'ANG MO KIO'")
plt.xlabel("hour")
plt.ylabel("avaliable rate %")
plt.grid()
# Out:
# LR prediction:
# r2 score: 0.03224503747925189
# mean absolute error: 0.05608590220383202

# %%
# SVR

# Standardize the data set
sc = StandardScaler()
sc.fit(july_x)
# not put X here because that will see the test set
july_x_std = sc.transform(july_x)
aug_x_std = sc.transform(aug_x)

july_y = average_area_july.loc[average_area_july['area'] == 20]\
       .drop(average_area_july.columns[[0]],axis=1).values[0]*100

svr = SVR(kernel='rbf',gamma='scale',degree = 5,C=0.8)
svr.fit(july_x_std,july_y)

july_predict = svr.predict(july_x_std)

# Plot
fig, ax = plt.subplots(1, 1, figsize=(10, 3))
ax.plot(range(0,31*24), july_predict, '-g')
ax.plot(range(0,31*24), july_y, '--k', ms=1)
#ax.set_xlim(0, 31*24)
#ax.set_ylim(0, 1)
ax.set_title("Avaliable rate for July 'BEDOK'")
plt.xlabel("hour")
plt.ylabel("avaliable rate %")
plt.grid()


aug_predict = svr.predict(aug_x_std)

aug_y = average_area_aug.loc[average_area_aug['area'] == 20]\
       .drop(average_area_aug.columns[[0]],axis=1).values[0]*100

print('SVR prediction:')
print(f'r2 score: {r2_score(aug_y,aug_predict)}')
print(f'mean absolute error: {mean_absolute_error(aug_y,aug_predict)/100}')

fig, ax = plt.subplots(1, 1, figsize=(10, 3))
ax.plot(range(0,31*24), aug_predict, '-g')
ax.plot(range(0,31*24), aug_y, '--k', ms=1)
#ax.set_xlim(0, 31*24)
#ax.set_ylim(0, 1)
ax.set_title("Avaliable rate for August 'BEDOK'")
plt.xlabel("hour")
plt.ylabel("avaliable rate %")
plt.grid()
# Out:
# SVR prediction:
# r2 score: 0.7544175775630498
# mean absolute error: 0.020245200615238556

# %%
# DT

july_y = average_area_july.loc[average_area_july['area'] == 80]\
       .drop(average_area_july.columns[[0]],axis=1).values[0]*100

dtr = DecisionTreeRegressor()
dtr.fit(july_x,july_y)

july_predict = dtr.predict(july_x)

# Plot
fig, ax = plt.subplots(1, 1, figsize=(10, 3))
ax.plot(range(0,31*24), july_predict, '-g')
ax.plot(range(0,31*24), july_y, '--k', ms=1)
#ax.set_xlim(0, 31*24)
#ax.set_ylim(0, 1)
ax.set_title("Avaliable rate for July 'JURONG EAST'")
plt.xlabel("hour")
plt.ylabel("avaliable rate %")
plt.grid()


aug_predict = dtr.predict(aug_x)

aug_y = average_area_aug.loc[average_area_aug['area'] == 80]\
       .drop(average_area_aug.columns[[0]],axis=1).values[0]*100

print('DT prediction:')
print(f'r2 score: {r2_score(aug_y,aug_predict)}')
print(f'mean absolute error: {mean_absolute_error(aug_y,aug_predict)/100}')

fig, ax = plt.subplots(1, 1, figsize=(10, 3))
ax.plot(range(0,31*24), aug_predict, '-g')
ax.plot(range(0,31*24), aug_y, '--k', ms=1)
#ax.set_xlim(0, 31*24)
#ax.set_ylim(0, 1)
ax.set_title("Avaliable rate for August 'JURONG EAST'")
plt.xlabel("hour")
plt.ylabel("avaliable rate %")
plt.grid()
# Out:
# DT prediction:
# r2 score: 0.8863694781100903
# mean absolute error: 0.012246082633674162

# %% [markdown]
# ### The above results show that we can classify the parking lots into areas, and predict the acailability of each area.
#
# **LR prediction:**
#
# r2 score:
#
# mean absolute error:
#
# **SVR prediction:**
#
# r2 score:
#
# mean absolute error:
#
# **DT prediction:**
#
# r2 score:
#
# mean absolute error:

# %% [markdown]
# ### Then we evaluate the avaliblity of every area by calculating the integration of the avaliable rate curve

# %%
def shortlevel(model,real,time):
    prediction = model.predict(time)
    pshortage = sum(prediction) / 31 /100
    rshortage = sum(real) / 31 /100
    return pshortage, rshortage

# %%
def shortmap():
    # using DT to calculate
    july_shortage,aug_shortage,pre_shortage = [],[],[]
    for i in july_div_area['area'].unique().astype(int): 

        july_y = average_area_july.loc[average_area_july['area'] == i]\
               .drop(average_area_july.columns[[0]],axis=1).values[0]*100

        dtr = DecisionTreeRegressor()
        dtr.fit(july_x,july_y)
        aug_predict = dtr.predict(aug_x)
        aug_y = average_area_aug.loc[average_area_aug['area'] == i]\
               .drop(average_area_aug.columns[[0]],axis=1).values[0]*100
        
        # calculate the shortlevel
        pre_s,aug_s = shortlevel(dtr,aug_y,aug_x)
        july_s = sum(july_y) / 31 /100
        july_shortage.append(july_s)
        aug_shortage.append(aug_s)
        pre_shortage.append(pre_s)
        
    return pre_shortage,july_shortage,aug_shortage

# %%
def normalize(data):
    avg = np.mean(data)
    mx = max(data)
    mn = min(data)
    return [(i - avg)/(mx - mn) for i in data]

# %%
sp,s7,s8 = shortmap()
portid = [i for i in july_div_area['area'].unique().astype(int)]
sortp = np.argsort(sp)
sort7 = np.argsort(s7)
sort8 = np.argsort(s8)
labelp = np.zeros(len(sp))
label7 = np.zeros(len(s7))
label8 = np.zeros(len(s8))
labelp[sortp[:3]] = np.ones(3)
label7[sort7[:3]] = np.ones(3)
label8[sort8[:3]] = np.ones(3)
labelp[sortp[-3:]] = -np.ones(3)
label7[sort7[-3:]] = -np.ones(3)
label8[sort8[-3:]] = -np.ones(3)

# %%
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        plt.text(rect.get_x()+rect.get_width()/2., 1.03*height, '%s' % float(height))

# %%
fig1 = plt.figure(2)
print('Need to build more park in :')
for i in range(len(s7)):
    Id = portid[i]
    shortage = sp[i]
    l = labelp[i]
    if l == 0:
        rects = plt.bar(Id,shortage,color=('b'),width = 1,align="center",yerr=0.000001)
    elif l == -1 :
        rects = plt.bar(Id,shortage,color=('g'),width = 1,align="center",yerr=0.000001)
    elif l == 1 :
        rects = plt.bar(Id,shortage,color=('r'),width = 1,align="center",yerr=0.000001)
        print(Id)
#     autolabel(rects)
    
plt.title('Predict park avaliblity level')
plt.show()
# Out:
# Need to build more park in :
# 44
# 62
# 101

# %%
fig1 = plt.figure(2)
print('Need to build more park in :')
for i in range(len(s7)):
    Id = portid[i]
    shortage = s7[i]
    l = label7[i]
    if l == 0:
        rects = plt.bar(Id,shortage,color=('b'),width = 1,align="center",yerr=0.000001)
    elif l == -1 :
        rects = plt.bar(Id,shortage,color=('g'),width = 1,align="center",yerr=0.000001)
    elif l == 1 :
        rects = plt.bar(Id,shortage,color=('r'),width = 1,align="center",yerr=0.000001)
        print(Id)
#     autolabel(rects)
    
plt.title('July park avaliability level')
plt.show()
# Out:
# Need to build more park in :
# 44
# 62
# 101

# %%
fig1 = plt.figure(2)
print('Need to build more park in :')
for i in range(len(s7)):
    Id = portid[i]
    shortage = s8[i]
    l = label8[i]
    if l == 0:
        rects = plt.bar(Id,shortage,color=('b'),width = 1,align="center",yerr=0.000001)
    elif l == -1 :
        rects = plt.bar(Id,shortage,color=('g'),width = 1,align="center",yerr=0.000001)
    elif l == 1 :
        rects = plt.bar(Id,shortage,color=('r'),width = 1,align="center",yerr=0.000001)
        print(Id)
#     autolabel(rects)
    
plt.title('August park avaliability level')
plt.show()
# Out:
# Need to build more park in :
# 44
# 62
# 101

# %% [markdown]
# ### 44 refers to the parks near Beach Road, 62 refers to Everton, 101 refers to Mei Lin St. These 3 area need new parks most

# %% [markdown]
# ## 3.2 two ways to predict the availability of a parking lot, firstly, we may only use the data of this particular parking lot; secondly, we may use the data of the parking lots in the near area.

# %% [markdown]
# ## We use carpark A100 in area10,  carpark BA1 in area 21 and  carpark H4 in area 70 to demonstrate the prediction of availability of a particular parking lot.

# %%
def preprocess(carpark_number):
    july_y = pd.read_csv("july_div_area.csv")
    july_y = july_y.loc[july_y['carpark_number']==carpark_number]
    july_y = july_y.drop(july_y.columns[[0,1,2]],axis=1)
    july_y = july_y.sum()
    
    aug_y = pd.read_csv("aug_div_area.csv")
    aug_y = aug_y.loc[aug_y['carpark_number']==carpark_number]
    aug_y = aug_y.drop(aug_y.columns[[0,1,2]],axis=1)
    aug_y = aug_y.sum()

    hour = [0,1,2]
    day = [0,1,2,3,4,5,6]
    week = [0,1,2,3]
    
    train_x = []
    train_y = []
    test_x = []
    test_y = []
    for i in range(744):
        h = int((i%24)/7) + 1
        day = int((i%192)/24) + 1
        week = int((i%768)/192) + 1
    
        train_x.append([h,day,week])
        train_y.append([july_y[i]])
        test_x.append([h,day,week])
        test_y.append(aug_y[i])
        
    train_x = np.array(train_x)
    train_y = np.array(train_y)   
    test_x = np.array(test_x)
    test_y = np.array(test_y)   
    
    return train_x,train_y,test_x,test_y

#Choose the carpark to be predicted

# train_x, train_y, test_x, test_y = preprocess('A100')
# train_x, train_y, test_x, test_y = preprocess('BA1')
train_x, train_y, test_x, test_y = preprocess('H17')



dtr = DecisionTreeRegressor()
lr = lm.LinearRegression()
svr = SVR(kernel='poly',gamma='scale',degree = 6,C=0.9)

svr.fit(train_x,train_y)
dtr.fit(train_x,train_y)
lr.fit(train_x,train_y)

test_y_dtr = dtr.predict(test_x)
test_y_lr = lr.predict(test_x)
test_y_svr = svr.predict(test_x)

#Plot the result of DT
fig, axs = plt.subplots(2, 1, figsize=(12, 9))
axs[0].plot(range(0,744), test_y*100, '--g',label = 'true value')
axs[0].plot(range(0,744), test_y_dtr*100, 'b-', ms=1,linewidth=0.95,label='predicted value')
axs[0].set_xlim(0, 7*24)
axs[0].set_ylim(0, 100)
axs[0].set_title("DTR")
axs[0].legend(loc=2)
plt.xlabel("hour")
plt.ylabel("avaliable rate")
plt.grid()

axs[1].plot(range(0,744), test_y*100, '--g',label = 'true value')
axs[1].plot(range(0,744), test_y_dtr*100, 'b-', ms=1,linewidth=0.95,label='predicted value')
axs[1].set_xlim(0, 24*31)
axs[1].set_ylim(0, 100)
axs[1].set_title("Time_Series_DTR")
plt.xlabel("hour")
plt.ylabel("avaliable rate")
plt.grid()
plt.legend(loc='upper left')


#Plot the result of LR
fig, axs = plt.subplots(2, 1, figsize=(12, 9))
axs[0].plot(range(0,744), test_y*100, '--g',label = 'true value')
axs[0].plot(range(0,744), test_y_lr*100, 'b-', ms=1,linewidth=0.95,label='predicted value')
axs[0].set_xlim(0, 7*24)
axs[0].set_ylim(0, 100)
axs[0].set_title("LR")
axs[0].legend(loc=2)
plt.xlabel("hour")
plt.ylabel("avaliable rate")
plt.grid()

axs[1].plot(range(0,744), test_y*100, '--g',label = 'true value')
axs[1].plot(range(0,744), test_y_lr*100, 'b-', ms=1,linewidth=0.95,label='predicted value')
axs[1].set_xlim(0, 24*31)
axs[1].set_ylim(0, 100)
axs[1].set_title("Time_Series_LR")
plt.xlabel("hour")
plt.ylabel("avaliable rate")
plt.grid()
plt.legend(loc='upper left')

#Plot the result of SVR
fig, axs = plt.subplots(2, 1, figsize=(12, 9))
axs[0].plot(range(0,744), test_y*100, '--g',label = 'true value')
axs[0].plot(range(0,744), test_y_svr*100, 'b-', ms=1,linewidth=0.95,label='predicted value')
axs[0].set_xlim(0, 7*24)
axs[0].set_ylim(0, 100)
axs[0].set_title("SVR")
axs[0].legend(loc=2)
plt.xlabel("hour")
plt.ylabel("avaliable rate")
plt.grid()

axs[1].plot(range(0,744), test_y*100, '--g',label = 'true value')
axs[1].plot(range(0,744), test_y_svr*100, 'b-', ms=1,linewidth=0.95,label='predicted value')
axs[1].set_xlim(0, 24*31)
axs[1].set_ylim(0, 100)
axs[1].set_title("Time_Series_SVR")
plt.xlabel("hour")
plt.ylabel("avaliable rate")
plt.grid()
plt.legend(loc='upper left')

# %%
def area_preprocess(area_number,carpark_number):
    #Get the average rate of the whole area
    whole_area_y = pd.read_csv("july_div_area.csv")
    whole_area_y = whole_area_y.loc[whole_area_y['area']==area_number]
    whole_area_y = whole_area_y.drop(whole_area_y.columns[[0,1,2]],axis=1)
    park_num = len(whole_area_y)
    whole_area_y = whole_area_y.sum()
    whole_area_y = whole_area_y.div(park_num)
    
    single_y = pd.read_csv("july_div_area.csv")
    single_y = single_y.loc[single_y['carpark_number']==carpark_number]
    single_y = single_y.drop(single_y.columns[[0,1,2]],axis=1)
    single_y = single_y.sum()
    
    
    whole_area = []
    single = []
    
    for i in range(744):
        whole_area.append([whole_area_y[i]])
        single.append(single_y[i])
        
    whole_area = np.array(train_y)   
    single = np.array(test_y)
    
    return whole_area, single

#Choose the carpark and area using the parameter
whole_area__y,single_y = area_preprocess(10,'A100')

#Show the difference between a single carpark and the carparks in the whole area
fig, axs = plt.subplots(2, 1, figsize=(12, 9))
axs[0].plot(range(0,744), train_y*100, '--g',label = 'Value of a Single carpark')
axs[0].plot(range(0,744), test_y*100, 'b-', ms=1,linewidth=0.95,label='Value of the carparks in the whole area')
axs[0].set_xlim(0, 7*24)
axs[0].set_ylim(0, 100)
axs[0].set_title("Comparison between a single carpark and carparks in the whole area")
axs[0].legend(loc=2)
plt.xlabel("hour")
plt.ylabel("avaliable rate")
plt.grid()

#The comparison within the whole time series
axs[1].plot(range(0,744), train_y*100, '--g',label = 'Value of a Single carpark')
axs[1].plot(range(0,744), test_y*100, 'b-', ms=1,linewidth=0.95,label='Value of the carparks in the whole area')
axs[1].set_xlim(0, 24*31)
axs[1].set_ylim(0, 100)
axs[1].set_title("Time_Series comparison between a single carpark and carparks in the whole area")
plt.xlabel("hour")
plt.ylabel("avaliable rate")
plt.grid()
plt.legend(loc='upper left')

# %% [markdown]
# ### As we can see, the difference between the rate of a particular carpark and the rate of carparks in the whole area is quite great, so we believe it's not appropriate to predict the availablility of a particular carpark using the rate data of the whole area.

# %% [markdown]
# ## 3.3 We can use the dataset to give drivers the real-time information of nearby parking lots and suggest them with the best alternative parking lot.

# %%
#concatenate the July and August Data
july_data=pd.read_csv('./july_div_area.csv')
aug_data=pd.read_csv('./aug_div_area.csv')
aug_data.drop(['area','carpark_number'],axis=1,inplace=True)
july_aug_data=pd.concat((july_data,aug_data),axis=1)

july_aug_data.drop(['Unnamed: 0'],axis=1,inplace=True)

columns_length=len(list(july_aug_data.columns))-2

#Labelize the column: data[carpark_number]
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
july_aug_data['carpark_number'] = le.fit_transform(july_aug_data['carpark_number'])

#convert pd to np
data=np.array(july_aug_data)

# %%
from sklearn.linear_model import LinearRegression as LR
from sklearn.tree import DecisionTreeRegressor as DTR
from sklearn.preprocessing import LabelEncoder

time_=list(july_aug_data.columns)
import time
from datetime import datetime


#decode the time to get the array
def time_process(time_str):
    valid_time_str=time_str[5:-2]
    valid_time_str=valid_time_str.split('_')
    decode_time_list=[]
    for i in valid_time_str:
        decode_time_list.append(int(i))
    return decode_time_list
    
        
        

for i in range(2,len(time_)):
    time_[i]=time_process(time_[i])


#show the total_time
time__=time_[2:-1]
# print(time__)

# %%
#  use the July data and the data before the test day as training data to simulate the available rate at the specific parking lot at test date.

def gui(carpark_number,date_time,threshold=0.6):
    
    carpark_number_=np.array([carpark_number])
    carpark_number_=le.transform(carpark_number_) #transform to the Lablel Encoder form
    #find the carpark_number belongs to which area
    area_number=0
    for i in range(len(july_aug_data)):
        if (july_aug_data.iloc[i,1])==carpark_number_:
            area_number=int(july_aug_data.iloc[i,0])
#             print(area_number)
            break

    
    date_time_list=time_process(date_time) #[month,day,hour,min]
#     print(date_time_list)
    time_index=0
    for j in range(len(time__)):
        if date_time_list[0] == time__[j][0]:#year
            if date_time_list[1]==time__[j][1]:#month
                if date_time_list[2]==time__[j][2]:#day
                    if date_time_list[3]<=time__[j][3]:#hour
                        time_index=j-1
                    elif date_time_list[3]>time__[j][3]:
                        time_index=j
    
#  params: train_x: carpark_number and time
#  params: train_y: available rate

    train_x=[]
    train_y=[]
    for i in range(len(data)):
        for j in range(2,time_index+3):
            tmp=[]
            tmp.append(data[i][1])#car_number
            tmp+=(time__[j])#add time
#             print(tmp)
            train_x.append(tmp) #(car_number,year,month,day,hour)
            train_y.append(data[i,j])
        
    train_x=np.array(train_x).reshape(len(train_x),5) #[len(data)*len(time_idx),(car_number,year,month,day,hour)]
    train_y=np.array(train_y) #[len(data)*len(time_idx),1]
    
    print('train_x.shape: ',train_x.shape)
    print('train_y.shape: ',train_y.shape)

    
#     print('x1',x1)
    x2=date_time_list
    x_predict=[]
    x_predict+=list(carpark_number_)
    x_predict+=x2
#     print('x_predict',x_predict)
    
    x_predic_=np.array(x_predict).reshape(1,len(x_predict)) #[1,5]
#     print(x_predic_.shape)
    #start training
    reg = DTR().fit(train_x, train_y)
    
#     print(x_predic.shape)
    res_rate=reg.predict(x_predic_)
#     print(reg.score(0.342629482071713,res_rate))
#     print(res_rate)
    if res_rate>=threshold:
        print('the available rate of the parking lot：{}'.format(res_rate[0]))
        print("there are enough parking lots, you can go!")
    else:
        print("the parking lots is a little crowded, the available rate now is :{}".format(res_rate[0]))
         #return two possible parking lots nearby where the available rate are above 60%
        res=[]
        res_rate_list=[]
        #search how many parking lots in the area of area_number，and predict the free parking lots
        for i in range(len(july_aug_data)):
            if july_aug_data.iloc[i,0]==area_number:
#                 print(july_aug_data.iloc[i,0])
                x1=july_aug_data.iloc[i,1]
                x2=date_time_list
                x_predict=[]
                x_predict.append(x1)
                x_predict+=x2
#                 print(x_predict)
                x_predic_=np.array(x_predict).reshape(1,len(x_predict))
                res_rate=reg.predict(x_predic_)
#                 print(res_rate)
                if res_rate>=threshold:
                    res_rate_list.append(res_rate)
                    res.append(july_aug_data.iloc[i,1])
                
        if len(res)>=2:

            print('In your destination Area:{x},recommend the nearby parking lots {y} and {z} to park,{y} parking lot  has available rate: {y1},\n{z} parking lot has available rate:{z1}'.format(x=area_number,y=le.inverse_transform(np.array([res[0]]))[0],z=le.inverse_transform(np.array([res[1]]))[0],y1=res_rate_list[0][0],z1=res_rate_list[1][0]))

# %%
def select_parklot():
    
    lot = str(input('please select the parking lot you wanna go, like A10:  '))
    while True:
        
        if not lot in july_data['carpark_number'].values:
            lot = str(input('the parking lot doesn\'t exist, please reinput: '))
        else:
            break
        
    day,hour = input('please choose the day of August you want to depature:  '),input('please choose the hour you may arrive in the day: ')
    date_time  = f'2022_8_{day}_{hour}_20_0'
    gui(lot,date_time,threshold=0.6)

# %%
select_parklot()
# Out:
# please select the parking lot you wanna go, like A10:  A10
# please choose the day of August you want to depature:  3
# please choose the hour you may arrive in the day: 21
# train_x.shape:  (1596732, 5)
# train_y.shape:  (1596732,)
# the parking lots is a little crowded, the available rate now is :0.068
# In your destination Area:10,recommend the nearby parking lots A100 and A2 to park,A100 parking lot  has available rate: 0.734375,
# A2 parking lot has available rate:0.6170212765957447
