# %% [markdown]
# # Project Question 2

# %% [markdown]
# # Forecasting

# %% [markdown]
# ## 2.1 Can you explain why you may want to forecast the carpark availability in the future? Who would find this information valuable? What can you do if you have a good forecasting model?

# %% [markdown]
# ### With the forecasted carpark availability, we can know the information in advance. The advanced information will help us make decision or take proper action.
#
# ### Drivers, government and the carpark management companies will find this information valuable.
# Drivers. They can schedule their parking in busy destination before they driving off, and even turn to public transport when facing parking anxiety.
#
# Government. They can use the advanced information for suggestions or reshedule of the new carparks.
#
# Carpark management companies. This information can not only help drivers to avoid choosing parking lots that are already full but also reduce the stress of parking lots with high flow.
#
# ### With a good forecasting model, we can provide this model to the government so that they can use it to improve their parking policies. We can also update the precision to the public so that every driver can plan their driving and parking more easily.

# %% [markdown]
# ## 2.2 Build a linear regression model to forecast the hourly carpark availability for a given month.
# Use the month of July 2022 as a training dataset and the month of August 2022 as the test dataset.
# ### Generate two plots:
# (i) Time series plot of the actual and predicted hourly values.
#
# (ii) Scatter plot of actual vs predicted hourly values (along with a line showing how good the fit is).

# %% [markdown]
# # Question 2 Part 2:

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import requests
import json
import pandas as pd
import datetime as dt
import os
import numpy as np
import random
import warnings
import sklearn.linear_model as lm
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PolynomialFeatures as PF
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Get training dataset

# %%
# grab certain time data and auto-repeat when "time out"
def timegraber_timeout(lstime = None):
    
    # input args processing
    if lstime is None:
        year = 2022
        month = 4
        day = 1
        hour = 0
        minute = 20
        second = 0 
    elif len(lstime) != 6:
        raise IndexError("lenght of list expects 6")
    else:
        year = lstime[0]
        month = lstime[1]
        day = lstime[2]
        hour = lstime[3]
        minute = lstime[4]
        second = lstime[5]
        
        # generate time
    Ddate = dt.datetime(year,month,day,hour,minute,second)

    # step
 #   deltat = dt.timedelta(hour = 1)
    loop = 1

    # update data
    while loop:

        # concatenate datetime
        date_time = f'date_time={str(Ddate.year)}-{str(Ddate.month).zfill(2)}-{str(Ddate.day).zfill(2)}T{str(Ddate.hour).zfill(2)}%3A{str(Ddate.minute).zfill(2)}%3A{str(Ddate.second).zfill(2)}'

        filename = f'EE4211carpark_date_{date_time}.json'
        # do not repeat download and write data
        if os.path.exists(filename) == False:
            # get API site
            site = f'https://api.data.gov.sg/v1/transport/carpark-availability?{date_time}'
            print(site)
            response_API = requests.get(site)
            data = response_API.text
            data = json.loads(data)

            # API may be timed out
            # when time out reget API
            if "message" in data:
                loop = 1
                print("time out")
                continue

            # no timed out then get timestamp
            timestamp = data['items'][0]["timestamp"]
            # get carpark data
            carpark = data['items'][0]["carpark_data"]
            with open(filename, 'w') as fp:
                json.dump(carpark, fp)

        # read file
        df = pd.read_json(filename)
        # reconstuct the frame of data
        for heading in ("total_lots","lot_type","lots_available"):
            df[heading] = df["carpark_info"].apply(lambda x: x[0][heading])
        df = df.drop(["carpark_info"], axis=1)
#        print(filename,"collected")
        loop = 0
        
    return df

# %%
# The start time of one-month interval
month = 7
day = 1
hour = 0
time_origin = [2022,month,day,hour,20,0]
df_origin = timegraber_timeout(time_origin)
#display(df_origin)

# Change the data to column name
colname = '_'.join(str(i) for i in time_origin)
#print(colname)

# Set up whole dataframe. Rename the column
total_number = df_origin.iloc[:,[0,3]]
df_whole = df_origin.rename(columns={'lots_available':colname})
df_whole = df_whole.drop(df_whole.columns[[1,2]],axis=1)


# Sort the whole dataframe
df_whole = df_whole.sort_values(by=['carpark_number','lot_type'])
#display(df_whole)

# Loop for a month

# gather new data
for day in range(1,32):
    for hour in range(24):
        time_new = [2022,month,day,hour,20,0]
        if time_new == time_origin:
            continue
        df_new = timegraber_timeout(time_new)
        # Change the data to column name
        colname = '_'.join(str(i) for i in time_new)
        #print(colname)
        # Rename the column
        new_number = df_new.iloc[:,[0,2,3]]
        df_new = df_new.rename(columns={'lots_available':colname})
        # Shape the new data
        
        df_new = df_new.drop(df_new.columns[[1,2]],axis=1)
        df_new = df_new.sort_values(by=['carpark_number','lot_type'])
        
        #display(df_new)
        #df_whole = pd.merge(df_whole,df_new,on=['carpark_number','total_lots','lot_type'],how='outer')
        df_whole = pd.merge(df_whole,df_new,on=['carpark_number','lot_type'],how='outer')
        total_number = pd.merge(total_number,new_number,on=['carpark_number','lot_type'],how='outer')
    print('Comparation finished for',day,'day.')
df_whole = df_whole.sort_values(by=['carpark_number','lot_type'])
display(df_whole)
total_number = total_number.sort_values(by=['carpark_number','lot_type'])
display(total_number)
# Out:
# Comparation finished for 1 day.
# Comparation finished for 2 day.
# Comparation finished for 3 day.
# Comparation finished for 4 day.
# Comparation finished for 5 day.
# Comparation finished for 6 day.
# Comparation finished for 7 day.
# Comparation finished for 8 day.
# Comparation finished for 9 day.
# Comparation finished for 10 day.
# Comparation finished for 11 day.
# Comparation finished for 12 day.
# Comparation finished for 13 day.
# Comparation finished for 14 day.
# Comparation finished for 15 day.
# Comparation finished for 16 day.
# Comparation finished for 17 day.
# Comparation finished for 18 day.
# Comparation finished for 19 day.
# Comparation finished for 20 day.
# Comparation finished for 21 day.
# Comparation finished for 22 day.
# Comparation finished for 23 day.
# Comparation finished for 24 day.
# Comparation finished for 25 day.
# Comparation finished for 26 day.
# Comparation finished for 27 day.
# Comparation finished for 28 day.
# Comparation finished for 29 day.
# Comparation finished for 30 day.
# Comparation finished for 31 day.
#      carpark_number lot_type 2022_7_1_0_20_0 2022_7_1_1_20_0 2022_7_1_2_20_0  \
# 0               A10        C              26              23              21
# 1              A100        C              36              35              35
# 2               A11        C             134             132             128
# 3               A12        C              88              87              86
# 4               A13        C              92              90              90
# ...             ...      ...             ...             ...             ...
# 1969             Y8        C             296             298             293
# 1970           Y82M        C             267             267             267
# 1971             Y9        C             108             110             108
# 1972            YHS        C              26              26              26
# 1988            YHS        Y             NaN             NaN             NaN
#
#      2022_7_1_3_20_0 2022_7_1_4_20_0 2022_7_1_5_20_0 2022_7_1_6_20_0  \
# 0                 21              21              21              23
# 1                 33              36              36              38
# 2                125             127             116             109
# 3                 87              87              85              94
# 4                 94              89              93              93
# ...              ...             ...             ...             ...
# 1969             276             277             280             307
# 1970             267             267             267             267
# 1971             107             106             111             120
# 1972              26              26              26              26
# 1988             NaN             NaN              31             NaN
#
#      2022_7_1_7_20_0  ... 2022_7_31_14_20_0 2022_7_31_15_20_0  \
# 0                 30  ...                14                16
# 1                 41  ...                39                37
# 2                118  ...               120               139
# 3                110  ...                95                98
# 4                121  ...                45                46
# ...              ...  ...               ...               ...
# 1969             385  ...               263               252
# 1970             267  ...               208               208
# 1971             135  ...                98                98
# 1972              26  ...                26                26
# 1988             NaN  ...               NaN               NaN
#
#      2022_7_31_16_20_0 2022_7_31_17_20_0 2022_7_31_18_20_0 2022_7_31_19_20_0  \
# 0                   15                16                17                19
# 1                   35                32                30                29
# 2                  145               160               151               135
# 3                  102               111                98                81
# 4                   61                43                 3                17
# ...                ...               ...               ...               ...
# 1969               246               242               218               238
# 1970               203               197               195               196
# 1971               120               115               116               106
# 1972                26                26                26                26
# 1988               NaN               NaN               NaN               NaN
#
#      2022_7_31_20_20_0 2022_7_31_21_20_0 2022_7_31_22_20_0 2022_7_31_23_20_0
# 0                   25                26                28                28
# 1                   29                29                28                26
# 2                  152               166               168               151
# 3                   87                89                90                94
# 4                   44                74                92                89
# ...                ...               ...               ...               ...
# 1969               287               298               290               295
# 1970               189               190               174               162
# 1971               108               130               137               126
# 1972                26                26                26                26
# 1988               NaN               NaN               NaN               NaN
#
# [2177 rows x 746 columns]
#      carpark_number lot_type total_lots_x total_lots_y total_lots_x  \
# 1249            A10        C           64           64           64
# 1464           A100        C           64           64           64
# 64              A11        C          368          368          368
# 36              A12        C          205          205          205
# 1706            A13        C          199          199          199
# ...             ...      ...          ...          ...          ...
# 531              Y8        C          697          697          697
# 1958           Y82M        C          341          341          341
# 352              Y9        C          262          262          262
# 971             YHS        C           64           64           64
# 1986            YHS        Y          NaN          NaN          NaN
#
#      total_lots_y total_lots_x total_lots_y total_lots_x total_lots_y  ...  \
# 1249           64           64           64           64           64  ...
# 1464           64           64           64           64           64  ...
# 64            368          368          368          368          368  ...
# 36            205          205          205          205          205  ...
# 1706          199          199          199          199          199  ...
# ...           ...          ...          ...          ...          ...  ...
# 531           697          697          697          697          697  ...
# 1958          341          341          341          341          341  ...
# 352           262          262          262          262          262  ...
# 971            64           64           64           64           64  ...
# 1986          NaN           55          NaN          NaN          NaN  ...
#
#      total_lots_y total_lots_x total_lots_y total_lots_x total_lots_y  \
# 1249           64           64           64           64           64
# 1464           64           64           64           64           64
# 64            368          368          368          368          368
# 36            205          205          205          205          205
# 1706          199          199          199          199          199
# ...           ...          ...          ...          ...          ...
# 531           697          697          697          697          697
# 1958          341          341          341          341          341
# 352           262          262          262          262          262
# 971            64           64           64           64           64
# 1986          NaN          NaN          NaN          NaN          NaN
#
#      total_lots_x total_lots_y total_lots_x total_lots_y total_lots
# 1249           64           64           64           64         64
# 1464           64           64           64           64         64
# 64            368          368          368          368        368
# 36            205          205          205          205        205
# 1706          199          199          199          199        199
# ...           ...          ...          ...          ...        ...
# 531           697          697          697          697        697
# 1958          341          341          341          341        341
# 352           262          262          262          262        262
# 971            64           64           64           64         64
# 1986          NaN          NaN          NaN          NaN        NaN
#
# [2177 rows x 745 columns]

# %%
july_whole = df_whole
july_total_lots = total_number
july_whole.to_csv('july_whole.csv')
july_total_lots.to_csv('july_total_lots.csv')

# %%
# Reset the index of the whole data
print('Origin data:')
df_whole = df_whole.reset_index(drop=True)
#display(df_whole)

print('Carparks without data for the most of time: ')
df_wholenan = df_whole[df_whole.isnull().T.any()]
#display(df_wholenan)

df_wholereal = df_whole.drop(df_wholenan.index)
df_wholereal = df_wholereal.reset_index(drop=True)
print('Cleaned data: ')
#display(df_wholereal)

# Deal with the total lots of each carpark
# Re_index
total_number = total_number.reset_index(drop=True)
# Clean nan
total_number_real = total_number.drop(df_wholenan.index)
total_number_real = total_number_real.reset_index(drop=True)
#display(total_number_real)
# Turn to int and get the one number of total lots of each
total_lots = total_number_real.drop(total_number_real.columns[[0,1]],axis=1).astype(int)
#display(total_lots)
print('The number of total lots of each carpark:')
total_lots_real = total_lots.T.max()
#display(total_lots_real)
# Out:
# Origin data:
# Carparks without data for the most of time:
# Cleaned data:
# The number of total lots of each carpark:

# %%
number_carpark = df_wholereal.drop(df_wholereal.columns[[0,1]],axis=1).astype(int)
#display(number_carpark)
number_carpark_sum = number_carpark.sum()
#display(number_carpark_sum)
total_lots_real_sum = total_lots_real.sum()
availrate_sum = number_carpark_sum.div(total_lots_real_sum)

# Plot
fig_sum,ax_sum=plt.subplots(figsize=(10, 5))
ax_sum.plot(availrate_sum)
plt.xlabel('The hours in April 2022 (2022-04-01-0:20 to 2022-04-30-23:20)')
#plt.ylabel('The index of each carpark')
plt.title('The percentage of available lots in whole')
plt.show()

# %% [markdown]
# ## Training model using July data

# %%
def dayfit(deg,weekday,week_sort,y_new):
    if weekday == 1 :
        start = 0
        end = list(week_sort).index(24)
    elif weekday > 1 and weekday < 7 :
        start = list(week_sort).index((weekday - 1) * 24)
        end = list(week_sort).index(weekday * 24)
    elif weekday == 7:
        start = list(week_sort).index((weekday - 1) * 24)
        end = len(week_sort)
        
    certainday = week_sort[start:end]
    certainday_value = y_new[start:end] * 100
    x_tr = np.array(range((weekday - 1) * 24,weekday * 24))
    
    # We create the model.
    lr = lm.LinearRegression()
#     X_poly = PF(degree=deg).fit_transform(certainday)
#     X_tr = PF(degree=deg).fit_transform(np.array(range(start,end)).reshape(-1,1))

    # We train the model on our training dataset.
    lr.fit(np.vander(certainday,deg + 1), certainday_value)
    # Now, we predict points with our trained model.
    y_lr = lr.predict(np.vander(x_tr, deg + 1))
    
    return list(y_lr)

# %%
y = list(availrate_sum)
week = list(np.linspace(0,7*24-1,7*24))
july = week[4*24:] + week + week + week + week
july = np.array(july).reshape(-1,1)

y_array = np.array(y)
week_sort = np.sort(july[:,0])
y_new = y_array[np.argsort(july[:,0])]

# %%
predict_rate = []
for i in range(1,8):
    prediction = dayfit(5,i,week_sort,y_new)
    predict_rate += prediction

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 3))
ax.plot(range(0,7*24), predict_rate, '--g')
ax.plot(july, [i * 100 for i in y], 'ok', ms=1)
ax.set_xlim(0, 7*24)
ax.set_ylim(0, 100)
ax.set_title("Avaliable rate for a week")
plt.xlabel("hour")
plt.ylabel("avaliable rate")
plt.grid()

# %% [markdown]
# ## Testing model using August data

# %% [markdown]
# ### load august data

# %%
# The start time of one-month interval
month = 8
day = 1
hour = 0
time_origin = [2022,month,day,hour,20,0]
df_origin = timegraber_timeout(time_origin)
#display(df_origin)

# Change the data to column name
colname = '_'.join(str(i) for i in time_origin)
#print(colname)

# Set up whole dataframe. Rename the column
total_number = df_origin.iloc[:,[0,3]]
df_whole = df_origin.rename(columns={'lots_available':colname})
df_whole = df_whole.drop(df_whole.columns[[1,2]],axis=1)


# Sort the whole dataframe
df_whole = df_whole.sort_values(by=['carpark_number','lot_type'])
#display(df_whole)

# Loop for a month

# gather new data
for day in range(1,32):
    for hour in range(24):
        time_new = [2022,month,day,hour,20,0]
        if time_new == time_origin:
            continue
        df_new = timegraber_timeout(time_new)
        # Change the data to column name
        colname = '_'.join(str(i) for i in time_new)
        #print(colname)
        # Rename the column
        new_number = df_new.iloc[:,[0,2,3]]
        df_new = df_new.rename(columns={'lots_available':colname})
        # Shape the new data
        
        df_new = df_new.drop(df_new.columns[[1,2]],axis=1)
        df_new = df_new.sort_values(by=['carpark_number','lot_type'])
        
        #display(df_new)
        #df_whole = pd.merge(df_whole,df_new,on=['carpark_number','total_lots','lot_type'],how='outer')
        df_whole = pd.merge(df_whole,df_new,on=['carpark_number','lot_type'],how='outer')
        total_number = pd.merge(total_number,new_number,on=['carpark_number','lot_type'],how='outer')
    print('Comparation finished for',day,'day.')
aug_whole = df_whole.sort_values(by=['carpark_number','lot_type'])
display(aug_whole)
aug_total_lots = total_number.sort_values(by=['carpark_number','lot_type'])
display(aug_total_lots)
# Out:
# Comparation finished for 1 day.
# Comparation finished for 2 day.
# Comparation finished for 3 day.
# Comparation finished for 4 day.
# Comparation finished for 5 day.
# Comparation finished for 6 day.
# Comparation finished for 7 day.
# Comparation finished for 8 day.
# Comparation finished for 9 day.
# Comparation finished for 10 day.
# Comparation finished for 11 day.
# Comparation finished for 12 day.
# Comparation finished for 13 day.
# Comparation finished for 14 day.
# Comparation finished for 15 day.
# Comparation finished for 16 day.
# Comparation finished for 17 day.
# Comparation finished for 18 day.
# Comparation finished for 19 day.
# Comparation finished for 20 day.
# Comparation finished for 21 day.
# Comparation finished for 22 day.
# Comparation finished for 23 day.
# Comparation finished for 24 day.
# Comparation finished for 25 day.
# Comparation finished for 26 day.
# Comparation finished for 27 day.
# Comparation finished for 28 day.
# Comparation finished for 29 day.
# Comparation finished for 30 day.
# Comparation finished for 31 day.
#      carpark_number lot_type 2022_8_1_0_20_0 2022_8_1_1_20_0 2022_8_1_2_20_0  \
# 0               A10        C              23              21              19
# 1              A100        C              26              27              27
# 2               A11        C             143             143             145
# 3               A12        C              93              91              90
# 4               A13        C              92              90              88
# ...             ...      ...             ...             ...             ...
# 1967             Y8        C             281             283             277
# 1968           Y82M        C             159             153             147
# 1969             Y9        C             128             130             130
# 1970            YHS        C              26              26              26
# 2085            YHS        Y             NaN             NaN             NaN
#
#      2022_8_1_3_20_0 2022_8_1_4_20_0 2022_8_1_5_20_0 2022_8_1_6_20_0  \
# 0                 19              18              17              18
# 1                 29              29              29              32
# 2                144             136             136             139
# 3                 90              90              92              94
# 4                 88              88              87              97
# ...              ...             ...             ...             ...
# 1967             267             265             274             301
# 1968             145             143             144             152
# 1969             129             129             128             138
# 1970              26              26              26              26
# 2085             NaN             NaN             NaN             NaN
#
#      2022_8_1_7_20_0  ... 2022_8_31_14_20_0 2022_8_31_15_20_0  \
# 0                 31  ...                34                34
# 1                 33  ...                52                47
# 2                170  ...               187               197
# 3                118  ...               160               155
# 4                113  ...                99               104
# ...              ...  ...               ...               ...
# 1967             366  ...               439               456
# 1968             181  ...               259               260
# 1969             150  ...               155               168
# 1970              26  ...                22                22
# 2085             NaN  ...               NaN               NaN
#
#      2022_8_31_16_20_0 2022_8_31_17_20_0 2022_8_31_18_20_0 2022_8_31_19_20_0  \
# 0                   34                34                34                34
# 1                   46                41                40                45
# 2                  200               193               191               167
# 3                  155               150               134               117
# 4                  110               108                86                80
# ...                ...               ...               ...               ...
# 1967               446               442               403               341
# 1968               260               257               252               224
# 1969               156               149               139               122
# 1970                22                22                22                22
# 2085               NaN               NaN               NaN               NaN
#
#      2022_8_31_20_20_0 2022_8_31_21_20_0 2022_8_31_22_20_0 2022_8_31_23_20_0
# 0                   34                34                34                34
# 1                   41                39                36                35
# 2                  155               150               138               131
# 3                  110               106                99                96
# 4                   40                73                75                85
# ...                ...               ...               ...               ...
# 1967               312               321               306               302
# 1968               210               199               186               169
# 1969               113               128               132               133
# 1970                22                22                22                22
# 2085               NaN               NaN               NaN               NaN
#
# [2165 rows x 746 columns]
#      carpark_number lot_type total_lots_x total_lots_y total_lots_x  \
# 1250            A10        C           64           64           64
# 1465           A100        C           64           64           64
# 64              A11        C          368          368          368
# 36              A12        C          205          205          205
# 1707            A13        C          199          199          199
# ...             ...      ...          ...          ...          ...
# 531              Y8        C          697          697          697
# 1954           Y82M        C          341          341          341
# 352              Y9        C          262          262          262
# 972             YHS        C           64           64           64
# 2085            YHS        Y          NaN          NaN          NaN
#
#      total_lots_y total_lots_x total_lots_y total_lots_x total_lots_y  ...  \
# 1250           64           64           64           64           64  ...
# 1465           64           64           64           64           64  ...
# 64            368          368          368          368          368  ...
# 36            205          205          205          205          205  ...
# 1707          199          199          199          199          199  ...
# ...           ...          ...          ...          ...          ...  ...
# 531           697          697          697          697          697  ...
# 1954          341          341          341          341          341  ...
# 352           262          262          262          262          262  ...
# 972            64           64           64           64           64  ...
# 2085          NaN          NaN          NaN          NaN          NaN  ...
#
#      total_lots_y total_lots_x total_lots_y total_lots_x total_lots_y  \
# 1250           64           64           64           64           64
# 1465           64           64           64           64           64
# 64            368          368          368          368          368
# 36            205          205          205          205          205
# 1707          199          199          199          199          199
# ...           ...          ...          ...          ...          ...
# 531           697          697          697          697          697
# 1954          341          341          341          341          341
# 352           262          262          262          262          262
# 972            64           64           64           64           64
# 2085          NaN          NaN          NaN          NaN          NaN
#
#      total_lots_x total_lots_y total_lots_x total_lots_y total_lots
# 1250           64           64           64           64         64
# 1465           64           64           64           64         64
# 64            368          368          368          368        368
# 36            205          205          205          205        205
# 1707          199          199          199          199        199
# ...           ...          ...          ...          ...        ...
# 531           697          697          697          697        697
# 1954          341          341          341          341        341
# 352           262          262          262          262        262
# 972            64           64           64           64         64
# 2085          NaN          NaN          NaN          NaN        NaN
#
# [2165 rows x 745 columns]

# %%
aug_whole.to_csv('aug_whole.csv')
aug_total_lots.to_csv('aug_total_lots.csv')

# %%
# %store
# Out:
# Stored variables and their in-db values:
# aug_total_lots              ->      carpark_number lot_type total_lots_x total_lo
# aug_whole                   ->      carpark_number lot_type 2022_8_1_0_20_0 2022_
# df_whole                    ->      carpark_number lot_type 2022_7_1_0_20_0 2022_
# july_total_lots             ->      carpark_number lot_type total_lots_x total_lo
# july_whole                  ->      carpark_number lot_type 2022_7_1_0_20_0 2022_
# total_number                ->      carpark_number lot_type total_lots_x total_lo

# %%
# Reset the index of the whole data
print('Origin data:')
df_whole = df_whole.reset_index(drop=True)
display(df_whole)

print('Carparks without data for the most of time: ')
df_wholenan = df_whole[df_whole.isnull().T.any()]
display(df_wholenan)

df_wholereal = df_whole.drop(df_wholenan.index)
df_wholereal = df_wholereal.reset_index(drop=True)
print('Cleaned data: ')
display(df_wholereal)

# Deal with the total lots of each carpark
# Re_index
total_number = total_number.reset_index(drop=True)
# Clean nan
total_number_real = total_number.drop(df_wholenan.index)
total_number_real = total_number_real.reset_index(drop=True)
#display(total_number_real)
# Turn to int and get the one number of total lots of each
total_lots = total_number_real.drop(total_number_real.columns[[0,1]],axis=1).astype(int)
#display(total_lots)
print('The number of total lots of each carpark:')
total_lots_real = total_lots.T.max()
display(total_lots_real)
# Out:
# Origin data:
#      carpark_number lot_type 2022_8_1_0_20_0 2022_8_1_1_20_0 2022_8_1_2_20_0  \
# 0               A10        C              23              21              19
# 1              A100        C              26              27              27
# 2               A11        C             143             143             145
# 3               A12        C              93              91              90
# 4               A13        C              92              90              88
# ...             ...      ...             ...             ...             ...
# 2160             Y8        C             281             283             277
# 2161           Y82M        C             159             153             147
# 2162             Y9        C             128             130             130
# 2163            YHS        C              26              26              26
# 2164            YHS        Y             NaN             NaN             NaN
#
#      2022_8_1_3_20_0 2022_8_1_4_20_0 2022_8_1_5_20_0 2022_8_1_6_20_0  \
# 0                 19              18              17              18
# 1                 29              29              29              32
# 2                144             136             136             139
# 3                 90              90              92              94
# 4                 88              88              87              97
# ...              ...             ...             ...             ...
# 2160             267             265             274             301
# 2161             145             143             144             152
# 2162             129             129             128             138
# 2163              26              26              26              26
# 2164             NaN             NaN             NaN             NaN
#
#      2022_8_1_7_20_0  ... 2022_8_31_14_20_0 2022_8_31_15_20_0  \
# 0                 31  ...                34                34
# 1                 33  ...                52                47
# 2                170  ...               187               197
# 3                118  ...               160               155
# 4                113  ...                99               104
# ...              ...  ...               ...               ...
# 2160             366  ...               439               456
# 2161             181  ...               259               260
# 2162             150  ...               155               168
# 2163              26  ...                22                22
# 2164             NaN  ...               NaN               NaN
#
#      2022_8_31_16_20_0 2022_8_31_17_20_0 2022_8_31_18_20_0 2022_8_31_19_20_0  \
# 0                   34                34                34                34
# 1                   46                41                40                45
# 2                  200               193               191               167
# 3                  155               150               134               117
# 4                  110               108                86                80
# ...                ...               ...               ...               ...
# 2160               446               442               403               341
# 2161               260               257               252               224
# 2162               156               149               139               122
# 2163                22                22                22                22
# 2164               NaN               NaN               NaN               NaN
#
#      2022_8_31_20_20_0 2022_8_31_21_20_0 2022_8_31_22_20_0 2022_8_31_23_20_0
# 0                   34                34                34                34
# 1                   41                39                36                35
# 2                  155               150               138               131
# 3                  110               106                99                96
# 4                   40                73                75                85
# ...                ...               ...               ...               ...
# 2160               312               321               306               302
# 2161               210               199               186               169
# 2162               113               128               132               133
# 2163                22                22                22                22
# 2164               NaN               NaN               NaN               NaN
#
# [2165 rows x 746 columns]
# Carparks without data for the most of time:
#      carpark_number lot_type 2022_8_1_0_20_0 2022_8_1_1_20_0 2022_8_1_2_20_0  \
# 68             AB26        C             NaN             NaN             NaN
# 71              ACM        Y             NaN             NaN             NaN
# 94             AR5M        Y             NaN             NaN             NaN
# 98              AR9        Y             NaN             NaN             NaN
# 331            BM14        Y             NaN             NaN             NaN
# ...             ...      ...             ...             ...             ...
# 1720            TE1        H               0             NaN             NaN
# 1721            TE1        Y             NaN             NaN             NaN
# 1870            TRM        C             NaN             NaN             NaN
# 1871            TRM        H             NaN             NaN             NaN
# 2164            YHS        Y             NaN             NaN             NaN
#
#      2022_8_1_3_20_0 2022_8_1_4_20_0 2022_8_1_5_20_0 2022_8_1_6_20_0  \
# 68               NaN             NaN             NaN             NaN
# 71               NaN             NaN             NaN             NaN
# 94               NaN             NaN             NaN             NaN
# 98               NaN             NaN             NaN             NaN
# 331              NaN             NaN             NaN             NaN
# ...              ...             ...             ...             ...
# 1720             NaN             NaN             NaN             NaN
# 1721             NaN             NaN             NaN             NaN
# 1870             NaN             NaN             NaN             NaN
# 1871             NaN             NaN             NaN             NaN
# 2164             NaN             NaN             NaN             NaN
#
#      2022_8_1_7_20_0  ... 2022_8_31_14_20_0 2022_8_31_15_20_0  \
# 68               NaN  ...               363               363
# 71               NaN  ...               NaN               NaN
# 94               NaN  ...                90               NaN
# 98               NaN  ...               NaN               NaN
# 331              NaN  ...               NaN               NaN
# ...              ...  ...               ...               ...
# 1720             NaN  ...               NaN               NaN
# 1721             NaN  ...               NaN               NaN
# 1870             NaN  ...               NaN               NaN
# 1871             NaN  ...               NaN               NaN
# 2164             NaN  ...               NaN               NaN
#
#      2022_8_31_16_20_0 2022_8_31_17_20_0 2022_8_31_18_20_0 2022_8_31_19_20_0  \
# 68                 363               363               363               363
# 71                 NaN               NaN               NaN               NaN
# 94                 NaN               NaN               NaN               NaN
# 98                 NaN               NaN               NaN               NaN
# 331                NaN               NaN               NaN               NaN
# ...                ...               ...               ...               ...
# 1720               NaN               NaN               NaN               NaN
# 1721               NaN               NaN               NaN               NaN
# 1870               NaN               NaN               NaN               NaN
# 1871               NaN               NaN               NaN               NaN
# 2164               NaN               NaN               NaN               NaN
#
#      2022_8_31_20_20_0 2022_8_31_21_20_0 2022_8_31_22_20_0 2022_8_31_23_20_0
# 68                 363               363               363               363
# 71                 NaN               NaN               NaN               NaN
# 94                 NaN               NaN               NaN               NaN
# 98                 NaN               NaN               NaN               NaN
# 331                NaN               NaN               NaN               NaN
# ...                ...               ...               ...               ...
# 1720               NaN               NaN               NaN               NaN
# 1721               NaN               NaN               NaN               NaN
# 1870               NaN               NaN               NaN               NaN
# 1871               NaN               NaN               NaN               NaN
# 2164               NaN               NaN               NaN               NaN
#
# [201 rows x 746 columns]
# Cleaned data:
#      carpark_number lot_type 2022_8_1_0_20_0 2022_8_1_1_20_0 2022_8_1_2_20_0  \
# 0               A10        C              23              21              19
# 1              A100        C              26              27              27
# 2               A11        C             143             143             145
# 3               A12        C              93              91              90
# 4               A13        C              92              90              88
# ...             ...      ...             ...             ...             ...
# 1959           Y78M        C              60              56              58
# 1960             Y8        C             281             283             277
# 1961           Y82M        C             159             153             147
# 1962             Y9        C             128             130             130
# 1963            YHS        C              26              26              26
#
#      2022_8_1_3_20_0 2022_8_1_4_20_0 2022_8_1_5_20_0 2022_8_1_6_20_0  \
# 0                 19              18              17              18
# 1                 29              29              29              32
# 2                144             136             136             139
# 3                 90              90              92              94
# 4                 88              88              87              97
# ...              ...             ...             ...             ...
# 1959              59              56              56              70
# 1960             267             265             274             301
# 1961             145             143             144             152
# 1962             129             129             128             138
# 1963              26              26              26              26
#
#      2022_8_1_7_20_0  ... 2022_8_31_14_20_0 2022_8_31_15_20_0  \
# 0                 31  ...                34                34
# 1                 33  ...                52                47
# 2                170  ...               187               197
# 3                118  ...               160               155
# 4                113  ...                99               104
# ...              ...  ...               ...               ...
# 1959             104  ...               154               164
# 1960             366  ...               439               456
# 1961             181  ...               259               260
# 1962             150  ...               155               168
# 1963              26  ...                22                22
#
#      2022_8_31_16_20_0 2022_8_31_17_20_0 2022_8_31_18_20_0 2022_8_31_19_20_0  \
# 0                   34                34                34                34
# 1                   46                41                40                45
# 2                  200               193               191               167
# 3                  155               150               134               117
# 4                  110               108                86                80
# ...                ...               ...               ...               ...
# 1959               163               152               145               124
# 1960               446               442               403               341
# 1961               260               257               252               224
# 1962               156               149               139               122
# 1963                22                22                22                22
#
#      2022_8_31_20_20_0 2022_8_31_21_20_0 2022_8_31_22_20_0 2022_8_31_23_20_0
# 0                   34                34                34                34
# 1                   41                39                36                35
# 2                  155               150               138               131
# 3                  110               106                99                96
# 4                   40                73                75                85
# ...                ...               ...               ...               ...
# 1959               116                99                81                79
# 1960               312               321               306               302
# 1961               210               199               186               169
# 1962               113               128               132               133
# 1963                22                22                22                22
#
# [1964 rows x 746 columns]
# The number of total lots of each carpark:
# 0       500
# 1        64
# 2       368
# 3       205
# 4       199
#        ...
# 1959    216
# 1960    697
# 1961    341
# 1962    262
# 1963     64
# Length: 1964, dtype: int64

# %%
number_carpark = df_wholereal.drop(df_wholereal.columns[[0,1]],axis=1).astype(int)
#display(number_carpark)
number_carpark_sum = number_carpark.sum()
#display(number_carpark_sum)
total_lots_real_sum = total_lots_real.sum()
availrate_sum = number_carpark_sum.div(total_lots_real_sum)

# Plot
fig_sum,ax_sum=plt.subplots(figsize=(10, 5))
ax_sum.plot(availrate_sum)
plt.xlabel('The hours in April 2022 (2022-04-01-0:20 to 2022-04-30-23:20)')
#plt.ylabel('The index of each carpark')
plt.title('The percentage of available lots in whole')
plt.show()

# %%
truth = list(availrate_sum)
week = list(np.linspace(0,7*24-1,7*24))
aug = week + week + week + week + week[:3*24]
aug = np.array(aug).reshape(-1,1)

y_array = np.array(y)
week_sort = np.sort(aug[:,0])
y_new = y_array[np.argsort(aug[:,0])]

aug_predict = predict_rate + predict_rate + predict_rate + predict_rate + predict_rate[:3*24]
print(len(aug_predict))
# Out:
# 744

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 3))
ax.plot(range(0,7*24), predict_rate, '-g')
ax.plot(aug, [i * 100 for i in truth], 'ok', ms=1)
ax.set_xlim(0, 7*24)
ax.set_ylim(0, 100)
ax.set_title("Avaliable rate for a week")
plt.xlabel("hour")
plt.ylabel("avaliable rate")
plt.grid()

# %% [markdown]
# ## Time series plot of the actual and predicted hourly values

# %%
# Plot
fig_sum,ax_sum=plt.subplots(figsize=(10, 5))
ax_sum.plot([i * 100 for i in truth])
ax_sum.plot(aug_predict)
plt.ylabel('The percentage of avaliable rate %')
plt.xlabel('Time serious in hours')
#plt.ylabel('The index of each carpark')
plt.title('The actual and predicted hourly values')
plt.show()

# %% [markdown]
# ## Scatter plot of actual vs predicted hourly values

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 3))
ax.plot(range(0,31*24), aug_predict, '-g')
ax.plot(range(0,31*24), [i * 100 for i in truth], 'ok', ms=1)
ax.set_xlim(0, 31*24)
ax.set_ylim(0, 100)
ax.set_title("Avaliable rate for August")
plt.xlabel("hour")
plt.ylabel("avaliable rate %")
plt.grid()

# %% [markdown]
# ## Error figure

# %%
Aug = np.array(truth) * 100
Aug_pre = np.array(aug_predict)
error = np.abs(Aug - Aug_pre)

# %%
plt.figure(figsize=(10, 6))

ax1 = plt.subplot(211)
ax1.plot(range(0,31*24), aug_predict, '-g')
ax1.plot(range(0,31*24), [i * 100 for i in truth], 'ok', ms=1)
ax1.set_xlim(0, 31*24)
ax1.set_ylim(0, 100)
ax1.set_title("Avaliable rate for August")
ax1.set_xlabel("hour")
ax1.set_ylabel("avaliable rate %")
ax1.grid()

ax = plt.subplot(212)
ax.plot(range(0,31*24), error)
ax.set_xlim(0, 31*24)
ax.set_ylim(0, 20)
ax.set_title("Error")
plt.xlabel("hour")
plt.ylabel("avaliable rate %")
plt.grid()
